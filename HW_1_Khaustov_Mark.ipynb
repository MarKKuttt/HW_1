# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from nltk import WordPunctTokenizer

# %%
data = pd.read_csv('liza.csv')
data = data['messages']
data.head()
# Out:
# 0    ['марк', 'так', 'что', 'вы', 'там', 'с', 'артё...
# 1    ['вся', 'инфа', 'упомянутая', 'в', 'нашей', 'б...
# 2    ['там', 'же', 'с', 'первого', 'раза', 'не', 'у...
# 3                                            ['капец']
# 4                                    ['это', 'правда']
# Name: messages, dtype: object

# %%
text = data

# %%
#
# Out:
# /var/folders/rr/39767lj15dg81g2dbl4jq3rw0000gn/T/ipykernel_8912/583209541.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   text = text.str.replace('[^а-яё ]', '')
# ['марк',
#  'так',
#  'что',
#  'вы',
#  'там',
#  'с',
#  'артёмом',
#  'делали',
#  'вся',
#  'инфа',
#  'упомянутая',
#  'в',
#  'нашей',
#  'беседе',
#  'конфиденциальна',
#  'там',
#  'же',
#  'с',
#  'первого',
#  'раза',
#  'не',
#  'у',
#  'всех',
#  'эффект',
#  'бывает',
#  'капец',
#  'это',
#  'правда',
#  'купи',
#  'второй',
#  'раз',
#  'и',
#  'проверь',
#  'ахха',
#  'зачем',
#  'кого',
#  'аххахахахаххахаахаххахахха',
#  'нашел',
#  'приключения',
#  'он',
#  'блин',
#  'выпил',
#  'серьезно',
#  'пиздец',
#  'просто',
#  'слов',
#  'нет',
#  'ну',
#  'че',
#  'мариккомарик',
#  'понравился',
#  'гаш',
#  'пхпхаххп',
#  'дорого',
#  'както',
#  'ну',
#  'может',
#  'второй',
#  'раз',
#  'реально',
#  'будет',
#  'лучше',
#  'а',
#  'артёму',
#  'как',
#  'он',
#  'же',
#  'уже',
#  'пробовал',
#  'ясно',
#  'ахаххахаххахахаххахахах',
#  'мб',
#  'не',
#  'мерещится',
#  'помоему',
#  'я',
#  'уже',
#  'об',
#  'этом',
#  'слышала',
#  'ктото',
#  'и',
#  'в',
#  'прямь',
#  'так',
#  'сделал',
#  'думаю',
#  'что',
#  'нет',
#  'я',
#  'боюсь',
#  'подобных',
#  'технологий',
#  'мне',
#  'кажется',
#  'если',
#  'бы',
#  'я',
#  'была',
#  'пещерным',
#  'человеком',
#  'я',
#  'бы',
#  'осталась',
#  'сидеть',
#  'в',
#  'пещере',
#  'я',
#  'вроде',
#  'объяснила',
#  'свою',
#  'позицию',
#  'пока',
#  'это',
#  'не',
#  'будет',
#  'у',
#  'большинства',
#  'людей',
#  'пока',
#  'не',
#  'увижу',
#  'что',
#  'с',
#  'ними',
#  'все',
#  'ок',
#  'не',
#  'поставлю',
#  'себе',
#  'обычный',
#  'человеческий',
#  'страх',
#  'а',
#  'ты',
#  'смотрел',
#  'токийский',
#  'гуль',
#  'а',
#  'ну',
#  'ок',
#  'тогда',
#  'я',
#  'попыталась',
#  'посмотреть',
#  'твоего',
#  'ванпачмана',
#  'но',
#  'чтото',
#  'не',
#  'пошло',
#  'я',
#  'не',
#  'знаю',
#  'стоит',
#  'ли',
#  'я',
#  'думала',
#  'может',
#  'ты',
#  'смотрел',
#  'и',
#  'хотела',
#  'спросить',
#  'совет',
#  'но',
#  'оно',
#  'вроде',
#  'многим',
#  'зашло',
#  'это',
#  'анимэ',
#  'ну',
#  'я',
#  'знаю',
#  'сюжет',
#  'и',
#  'первую',
#  'серию',
#  'когдато',
#  'смотрела',
#  'а',
#  'поняла',
#  'сообщения',
#  'выше',
#  'не',
#  'прочла',
#  'вхаххахахаххаххаха',
#  'трейлер',
#  'выглядит',
#  'как',
#  'законченный',
#  'фильм',
#  'постер',
#  'выглядит',
#  'очень',
#  'круто',
#  'а',
#  'там',
#  'что',
#  'ли',
#  'инструкции',
#  'не',
#  'было',
#  'действительно',
#  'уже',
#  'неактуально',
#  'но',
#  'ее',
#  'я',
#  'раньше',
#  'прочитала',
#  'значит',
#  'он',
#  'заболел',
#  'короной',
#  'а',
#  'мне',
#  'кажется',
#  'многие',
#  'болели',
#  'хорошо',
#  'что',
#  'у',
#  'него',
#  'это',
#  'незаметно',
#  'прошло',
#  'ты',
#  'можешь',
#  'спросить',
#  'у',
#  'артема',
#  'код',
#  'от',
#  'конфы',
#  'по',
#  'инфе',
#  'пожалуйста',
#  'поняла',
#  'все',
#  'равно',
#  'спасибо',
#  'видимо',
#  'задвину',
#  'не',
#  'помню',
#  'ща',
#  'гляну',
#  'в',
#  'было',
#  'чтото',
#  'задано',
#  'бля',
#  'лю',
#  'пиздец',
#  'злая',
#  'сегодня',
#  'электромагнитные',
#  'бури',
#  'противоречиво',
#  'а',
#  'чей',
#  'крым',
#  'на',
#  'вопрос',
#  'вопросом',
#  'не',
#  'отвечают',
#  'неправда',
#  'ты',
#  'спросил',
#  'как',
#  'я',
#  'считаю',
#  'после',
#  'заданного',
#  'мной',
#  'вопроса',
#  'но',
#  'тем',
#  'не',
#  'менее',
#  'чей',
#  'вопрос',
#  'выше',
#  'правильно',
#  'мой',
#  'можно',
#  'но',
#  'факт',
#  'есть',
#  'факт',
#  'бесполезный',
#  'точнее',
#  'какую',
#  'вторую',
#  'часть',
#  'по',
#  'математике',
#  'или',
#  'нет',
#  'на',
#  'сегодня',
#  'сейчас',
#  'кину',
#  'геометрию',
#  'не',
#  'делала',
#  'если',
#  'будут',
#  'вопросы',
#  'пиши',
#  'ты',
#  'идешь',
#  'на',
#  'френ',
#  'есть',
#  'номер',
#  'сони',
#  'гершкович',
#  'аххахахахаххахах',
#  'первое',
#  'июня',
#  'праздник',
#  'ребенка',
#  'весьма',
#  'кстати',
#  'будет',
#  'пьянка',
#  'нет',
#  'последнее',
#  'предложение',
#  'в',
#  'кавычках',
#  'это',
#  'возможно',
#  'это',
#  'самое',
#  'глупое',
#  'не',
#  'учиться',
#  'на',
#  'своих',
#  'ошибках',
#  'всегда',
#  'печально',
#  'марк',
#  'есть',
#  'какието',
#  'новости',
#  'по',
#  'поводу',
#  'пароля',
#  'от',
#  'френа',
#  'ура',
#  'возможно',
#  'нет',
#  'это',
#  'что',
#  'за',
#  'игна',
#  'вот',
#  'когда',
#  'ты',
#  'в',
#  'следующих',
#  'раз',
#  'спросишь',
#  'могу',
#  'ли',
#  'я',
#  'кинуть',
#  'тебе',
#  'дз',
#  'я',
#  'тебе',
#  'просто',
#  'отвечу',
#  'да',
#  'могу',
#  'и',
#  'все',
#  'а',
#  'ну',
#  'теперь',
#  'понятно',
#  'это',
#  'фильм',
#  'умная',
#  'дама',
#  'кажется',
#  'у',
#  'меня',
#  'вотвот',
#  'начнётся',
#  'никотиновое',
#  'голодание',
#  'тк',
#  'жижа',
#  'заканчивается',
#  'надеюсь',
#  'что',
#  'я',
#  'буду',
#  'нормальной',
#  'в',
#  'этот',
#  'период',
#  'это',
#  'обязанность',
#  'папы',
#  'она',
#  'мне',
#  'это',
#  'уже',
#  'сегодня',
#  'сказала',
#  'это',
#  'птица',
#  'а',
#  'не',
#  'штука',
#  'ищешь',
#  'себе',
#  'собеседника',
#  'который',
#  'выслушает',
#  'всю',
#  'твою',
#  'бредятину',
#  'в',
#  'дни',
#  'запоев',
#  'боюсь',
#  'что',
#  'даже',
#  'он',
#  'это',
#  'не',
#  'выдержит',
#  'ну',
#  'мучай',
#  'животных',
#  'иначе',
#  'натравлб',
#  'на',
#  'тебя',
#  'лблей',
#  'борющихся',
#  'за',
#  'защиту',
#  'животных',
#  'я',
#  'думала',
#  'змеи',
#  'тебе',
#  'больше',
#  'подуше',
#  'тут',
#  'ты',
#  'должен',
#  'сказать',
#  'что',
#  'тебе',
#  'и',
#  'меня',
#  'хватает',
#  'я',
#  'бы',
#  'не',
#  'рискнула',
#  'так',
#  'назватт',
#  'ну',
#  'значит',
#  'и',
#  'тебя',
#  'ведь',
#  'я',
#  'умнее',
#  'тебя',
#  'может',
#  'но',
#  'не',
#  'факт',
#  'что',
#  'проживёт',
#  'а',
#  'кому',
#  'она',
#  'должна',
#  'россии',
#  'честно',
#  'голос',
#  'хороший',
#  'фальшивит',
#  'но',
#  'это',
#  'решаемые',
#  'вопрос',
#  'а',
#  'на',
#  'это',
#  'я',
#  'не',
#  'обратила',
#  'внимания',
#  'чтото',
#  'было',
#  'задано',
#  'по',
#  'математике',
#  'как',
#  'ты',
#  'об',
#  'этом',
#  'узнал',
#  'что',
#  'это',
#  'ща',
#  'параша',
#  'сразу',
#  'видно',
#  'бот',
#  'какойто',
#  'типо',
#  'у',
#  'тебя',
#  'своих',
#  'фоток',
#  'нет',
#  'поэтому',
#  'пришлось',
#  'взять',
#  'фото',
#  'своих',
#  'врагов',
#  'у',
#  'меня',
#  'естт',
#  'сейчас',
#  'пришлю',
#  'ты',
#  'на',
#  'фотках',
#  'полнейший',
#  'угар',
#  'и',
#  'редкий',
#  'феномен',
#  'тк',
#  'тебя',
#  'сфоткать',
#  'нереально',
#  'а',
#  'почему',
#  'все',
#  'в',
#  'аниме',
#  'стиле',
#  'хрень',
#  'поч',
#  'поч',
#  'с',
#  'опытом',
#  'видимо',
#  'я',
#  'думала',
#  'надо',
#  'ли',
#  'оно',
#  'мне',
#  'надо',
#  'оки',
#  'оооо',
#  'можно',
#  'так',
#  'выкладывать',
#  'выглядит',
#  'прикольно',
#  'и',
#  'тебя',
#  'вххахахаххаххаха',
#  'серьезно',
#  'знал',
#  'я',
#  'вообще',
#  'бы',
#  'не',
#  'подумаоа',
#  'но',
#  'только',
#  'если',
#  'бы',
#  'это',
#  'не',
#  'сережа',
#  'писал',
#  'вот',
#  'это',
#  'да',
#  'вот',
#  'это',
#  'вау',
#  'ахахахахаххахаха',
#  'хвхахаххахаххахахах',
#  'очень',
#  'нравиться',
#  'мне',
#  'такоеодобряю',
#  'вххахахаххахахахха',
#  'как',
#  'красиво',
#  'так',
#  'это',
#  'что',
#  'обман',
#  'да',
#  'неважно',
#  'какие',
#  'а',
#  'у',
#  'тебя',
#  'скока',
#  'ты',
#  'еще',
#  'падал',
#  'этой',
#  'зимой',
#  'в',
#  'плане',
#  'что',
#  'значит',
#  'конечно',
#  'в',
#  'твоем',
#  'случае',
#  'это',
#  'не',
#  'применимо',
#  'не',
#  'но',
#  'мне',
#  'кажется',
#  'что',
#  'изза',
#  'того',
#  'что',
#  'я',
#  'один',
#  'раз',
#  'не',
#  'позволила',
#  'себе',
#  'упасть',
#  'нога',
#  'потерпела',
#  'поражение',
#  'болит',
#  'немного',
#  'ну',
#  'типо',
#  'чтобы',
#  'удержаться',
#  'нужно',
#  'много',
#  'сил',
#  'мб',
#  'перенапрягла',
#  'ее',
#  'а',
#  'может',
#  'об',
#  'стул',
#  'стукнулась',
#  'а',
#  'я',
#  'начала',
#  'носить',
#  'ботинки',
#  'но',
#  'осенние',
#  'а',
#  'челси',
#  'тебе',
#  'не',
#  'нрав',
#  'это',
#  'модели',
#  'не',
#  'бренд',
#  'да',
#  'хотя',
#  'зима',
#  'уже',
#  'подходит',
#  'к',
#  'концу',
#  'ты',
#  'любишь',
#  'техно',
#  'и',
#  'кстати',
#  'ваня',
#  'сказал',
#  'что',
#  'ты',
#  'ищешь',
#  'смысл',
#  'в',
#  'тату',
#  'зач',
#  'и',
#  'поч',
#  'можно',
#  'же',
#  'просто',
#  'красиво',
#  'мысли',
#  'гениев',
#  'сходятся',
#  'хахаххахахаха',
#  'а',
#  'тебе',
#  'он',
#  'нужен',
#  'вххахахахахаххахах',
#  'короче',
#  'ты',
#  'цже',
#  'решился',
#  'бить',
#  'да',
#  'ты',
#  'искал',
#  'еще',
#  'какихто',
#  'челиков',
#  'я',
#  'нашла',
#  'студию',
#  'мини',
#  'тату',
#  'только',
#  'в',
#  'которой',
#  'у',
#  'меня',
#  'подруга',
#  'била',
#  'там',
#  'дешевле',
#  'но',
#  'хз',
#  'мини',
#  'ди',
#  'у',
#  'меня',
#  'по',
#  'факту',
#  'у',
#  'меня',
#  'к',
#  'на',
#  'тату',
#  'есть',
#  'сейчас',
#  'тебе',
#  'цена',
#  'такая',
#  'мне',
#  'она',
#  'написала',
#  'что',
#  'моя',
#  'татушка',
#  'будет',
#  'в',
#  'районе',
#  'зависит',
#  'от',
#  'конечного',
#  'эскиза',
#  'я',
#  'написала',
#  'размер',
#  'х',
#  'а',
#  'твои',
#  'родители',
#  'в',
#  'курсе',
#  'даже',
#  'слишком',
#  'ого',
#  'вот',
#  'это',
#  'жаба',
#  'вот',
#  'это',
#  'класс',
#  'вххахахахаххахаха',
#  'вххахахаххахахах',
#  'не',
#  'так',
#  'сильно',
#  'как',
#  'лягушки',
#  'и',
#  'жабы',
#  'взгляните',
#  'на',
#  'это',
#  'это',
#  'доброе',
#  'утро',
#  'или',
#  'спокойной',
#  'ночи',
#  'нет',
#  'я',
#  'еще',
#  'и',
#  'заболела',
#  'мне',
#  'нравятся',
#  'эти',
#  'чуваки',
#  'все',
#  'больше',
#  'и',
#  'больше',
#  'похоже',
#  'на',
#  'то',
#  'спасибо',
#  'тебе',
#  'удачи',
#  'на',
#  'экзе',
#  'да',
#  'у',
#  'меня',
#  'была',
#  'темпа',
#  'дня',
#  'сейчас',
#  'горло',
#  'тревожит',
#  'а',
#  'в',
#  'остальном',
#  'бодрячком',
#  'дааа',
#  'сейчас',
#  'с',
#  'этим',
#  'жопа',
#  'вххахахаххахахаххаха',
#  'может',
#  'он',
#  'непонятый',
#  'гений',
#  'а',
#  'ты',
#  'не',
#  'знаешь',
#  'почему',
#  'в',
#  'моей',
#  'игрушке',
#  'слово',
#  'читер',
#  'запрещенное',
#  'слово',
#  'не',
#  'я',
#  'раньше',
#  'много',
#  'играла',
#  'типа',
#  'фортнайта',
#  'и',
#  'там',
#  'в',
#  'чате',
#  'запрещено',
#  'слово',
#  'читер',
#  'помоему',
#  'его',
#  'нельзя',
#  'написатт',
#  'о',
#  'мой',
#  'бог',
#  'аа',
#  'меня',
#  'обижают',
#  'спидаки',
#  'что',
#  'делать',
#  'нечестно',
#  'получается',
#  'чтоо',
#  'это',
#  'где',
#  'такое',
#  'и',
#  'как',
#  'обидеть',
#  'вербально',
#  'вхаххахахаххаххахах',
#  'больше',
#  'ни',
#  'во',
#  'что',
#  'я',
#  'месяца',
#  'два',
#  'назад',
#  'неожиданно',
#  'правилась',
#  'с',
#  'зависимостью',
#  'к',
#  'играм',
#  'желание',
#  'просто',
#  'пропала',
#  'несколько',
#  'лет',
#  'не',
#  'пропадало',
#  'и',
#  'тут',
#  'вот',
#  'тебе',
#  'на',
#  'само',
#  'собой',
#  'только',
#  'англ',
#  'еще',
#  'есть',
#  'фр',
#  'и',
#  'нем',
#  'но',
#  'я',
#  'выбрала',
#  'англ',
#  'ааа',
#  'с',
#  'джава',
#  'в',
#  'следющем',
#  'семестре',
#  'питон',
#  'самые',
#  'основные',
#  'полина',
#  'узнала',
#  'через',
#  'знакомых',
#  'какие',
#  'языки',
#  'сейчас',
#  'нужны',
#  'вот',
#  'эти',
#  'три',
#  'и',
#  'назвала',
#  'только',
#  'нас',
#  'так',
#  'учат',
#  'работы',
#  'дают',
#  'и',
#  'проверяют',
#  'остальное',
#  'сам',
#  'типо',
#  'сложно',
#  'по',
#  'сути',
#  'самообучение',
#  'но',
#  'под',
#  'присмотром',
#  'но',
#  'в',
#  'этом',
#  'году',
#  'по',
#  'джаве',
#  ...]

# %%
data = [x.replace('\t', ' ') for x in data]
data = [x.replace('\n', ' ') for x in data]
data = [x.replace('\r', ' ') for x in data]
data = [x.replace('"', '') for x in data]
data = [x.replace("'", '') for x in data]
data = [x for x in data if x != ' ']
data = [x for x in data if x != '']
data = [x for x in data if len(x.split()) > 1]

# delete more than 1 spaces
data = [x.replace('  ', ' ') for x in data]
data = [x.replace('   ', ' ') for x in data]
data = [x.replace('    ', ' ') for x in data]
data = [x.replace('     ', ' ') for x in data]

data
# Out:
# ['[марк, так, что, вы, там, с, артёмом, делали]',
#  '[вся, инфа, упомянутая, в, нашей, беседе, конфиденциальна]',
#  '[там, же, с, первого, раза, не, у, всех, эффект, бывает]',
#  '[это, правда]',
#  '[купи, второй, раз]',
#  '[и, проверь]',
#  '[нашел, приключения]',
#  '[он, блин, выпил]',
#  '[просто, слов, нет]',
#  '[ну, че]',
#  '[понравился, гаш]',
#  '[ну, может, второй, раз, реально, будет, лучше]',
#  '[а, артёму, как]',
#  '[он, же, уже, пробовал]',
#  '[мб, не, мерещится]',
#  '[я, уже, об, этом, слышала]',
#  '[кто-то, и, в, прямь, так, сделал]',
#  '[думаю, что, нет]',
#  '[я, боюсь, подобных, технологий]',
#  '[мне, кажется]',
#  '[если, бы, я, была, пещерным, человеком]',
#  '[я, бы, осталась, сидеть, в, пещере]',
#  '[я, вроде, объяснила, свою, позицию]',
#  '[пока, это, не, будет, у, большинства, людей]',
#  '[пока, не, увижу]',
#  '[что, с, ними, все, ок]',
#  '[не, поставлю, себе]',
#  '[человеческий, страх]',
#  '[а, ты, смотрел, токийский, гуль]',
#  '[ну, ок, тогда]',
#  '[я, попыталась, посмотреть, твоего, ванпачмана]',
#  '[но, что-то, не, пошло]',
#  '[я, не, знаю, стоит, ли]',
#  '[я, думала, может, ты, смотрел]',
#  '[и, хотела, спросить, совет]',
#  '[999, %]',
#  '[но, оно, вроде, многим, зашло]',
#  '[это, анимэ]',
#  '[ну, я, знаю, сюжет]',
#  '[и, первую, серию, когда-то, смотрела]',
#  '[сообщения, выше, не, прочла]',
#  '[трейлер, выглядит, как, законченный, фильм]',
#  '[постер, выглядит, очень, круто]',
#  '[а, там, что, ли, инструкции, не, было]',
#  '[уже, неактуально]',
#  '[но, ее, я, раньше, прочитала]',
#  '[он, заболел, короной]',
#  '[мне, кажется, многие, болели]',
#  '[хорошо, что, у, него, это, незаметно, прошло]',
#  '[ты, можешь, спросить, у, артема]',
#  '[код, от, конфы]',
#  '[по, инфе]',
#  '[все, равно, спасибо]',
#  '[не, помню]',
#  '[ща, гляну]',
#  '[в, 3]',
#  '[было, что-то, задано]',
#  '[лю, пиздец]',
#  '[электромагнитные, бури]',
#  '[а, чей, крым]',
#  '[на, вопрос, вопросом, не, отвечают]',
#  '[ты, спросил]',
#  '[как, я, считаю]',
#  '[после, заданного, мной, вопроса]',
#  '[но, тем, не, менее]',
#  '[чей, вопрос, выше]',
#  '[но, факт]',
#  '[есть, факт]',
#  '[какую, вторую, часть]',
#  '[по, математике]',
#  '[или, нет]',
#  '[на, сегодня]',
#  '[сейчас, кину]',
#  '[геометрию, не, делала]',
#  '[если, будут]',
#  '[ты, идешь, на, френ]',
#  '[есть, номер, сони]',
#  '[первое, июня]',
#  '[праздник, ребенка]',
#  '[весьма, кстати, будет, пьянка]',
#  '[последнее, предложение, в, кавычках]',
#  '[это, возможно]',
#  '[это, самое, глупое]',
#  '[не, учиться, на, своих, ошибках]',
#  '[есть, какие-то, новости]',
#  '[по, поводу, пароля]',
#  '[от, френа]',
#  '[возможно, нет]',
#  '[это, что, за, игна]',
#  '[вот, когда, ты, в, следующих, раз, спросишь, могу, ли, я, кинуть, тебе, дз]',
#  '[я, тебе, просто, отвечу, да]',
#  '[и, все]',
#  '[ну, теперь, понятно]',
#  '[это, фильм]',
#  '[умная, дама]',
#  '[кажется, у, меня, вот-вот, начнётся, никотиновое, голодание]',
#  '[тк, жижа, заканчивается]',
#  '[надеюсь, что, я, буду, нормальной, в, этот, период]',
#  '[это, обязанность, папы]',
#  '[она, мне, это, уже, сегодня, сказала]',
#  '[это, птица]',
#  '[а, не, штука]',
#  '[ищешь, себе, собеседника, который, выслушает, всю, твою, бредятину, в, дни, запоев]',
#  '[что, даже, он, это, не, выдержит]',
#  '[ну, мучай, животных]',
#  '[иначе, натравлб, на, тебя]',
#  '[лблей, борющихся, за, защиту, животных]',
#  '[я, думала, змеи, тебе, больше, по-душе]',
#  '[тут, ты]',
#  '[должен, сказать]',
#  '[что, тебе, и, меня, хватает]',
#  '[я, бы, не, рискнула, так, назватт]',
#  '[ну, значит, и, тебя]',
#  '[ведь, я]',
#  '[умнее, тебя]',
#  '[но, не, факт, что, проживёт]',
#  '[а, кому, она, должна]',
#  '[голос, хороший]',
#  '[но, это, решаемые, вопрос]',
#  '[на, это, я, не, обратила, внимания]',
#  '[что-то, было, задано, по, математике]',
#  '[как, ты, об, этом, узнал]',
#  '[что, это, ща, параша]',
#  '[сразу, видно]',
#  '[бот, какой-то]',
#  '[типо, у, тебя, своих, фоток, нет]',
#  '[поэтому, пришлось, взять, фото, своих, врагов]',
#  '[у, меня, естт]',
#  '[сейчас, пришлю]',
#  '[ты, на, фотках, полнейший, угар]',
#  '[и, редкий, феномен]',
#  '[тк, тебя, сфоткать, нереально]',
#  '[а, почему, все, в, аниме, стиле]',
#  '[поч, поч]',
#  '[с, опытом, видимо]',
#  '[я, думала, надо, ли, оно, мне]',
#  '[можно, так, выкладывать]',
#  '[выглядит, прикольно]',
#  '[и, тебя]',
#  '[серьезно, знал]',
#  '[я, вообще, бы, не, подумаоа]',
#  '[но, только, если, бы, это, не, сережа, писал]',
#  '[вот, это, да]',
#  '[вот, это, вау]',
#  '[очень, нравиться, мне, такоеодобряю]',
#  '[как, красиво]',
#  '[так, это, что]',
#  '[5, o, ’, clock]',
#  '[да, неважно, какие]',
#  '[а, у, тебя, скока]',
#  '[ты, еще, падал, этой, зимой]',
#  '[в, плане]',
#  '[что, значит, конечно]',
#  '[в, твоем, случае, это, не, применимо]',
#  '[но, мне, кажется]',
#  '[что, из-за, того, что, я, один, раз, не, позволила, себе, упасть, нога, потерпела, поражение]',
#  '[болит, немного]',
#  '[ну, типо]',
#  '[чтобы, удержаться, нужно, много, сил]',
#  '[мб, перенапрягла, ее]',
#  '[а, может, об, стул, стукнулась]',
#  '[а, я, начала, носить, ботинки, но, осенние]',
#  '[а, челси, тебе, не, нрав]',
#  '[это, модели]',
#  '[не, бренд]',
#  '[хотя, зима, уже, подходит, к, концу]',
#  '[ты, любишь, техно]',
#  '[и, кстати]',
#  '[ваня, сказал, что, ты, ищешь, смысл, в, тату]',
#  '[зач, и, поч]',
#  '[можно, же, просто, красиво]',
#  '[мысли, гениев, сходятся]',
#  '[а, тебе, он, нужен]',
#  '[ты, цже, решился]',
#  '[ты, искал, еще, каких-то, челиков]',
#  '[я, нашла, студию, мини, тату, только, в, которой, у, меня, подруга, била]',
#  '[там, дешевле, но, хз, мини, ди, у, меня]',
#  '[по, факту, у, меня, 6к, на, тату, есть, сейчас]',
#  '[тебе, цена, такая]',
#  '[мне, она, написала, что, моя, татушка, будет, в, районе, 7, зависит, от, конечного, эскиза, я, написала, размер, 3х4]',
#  '[а, твои, родители, в, курсе]',
#  '[даже, слишком]',
#  '[ого, вот, это, жаба]',
#  '[вот, это, класс]',
#  '[не, так, сильно, как, лягушки, и, жабы…]',
#  '[взгляните, на, это…, 👀\\\\n, link, https//pinit/2iqsz0y]',
#  '[это, доброе, утро, или, спокойной, ночи]',
#  '[я, еще, и, заболела]',
#  '[мне, нравятся, эти, чуваки, все, больше, и, больше]',
#  '[похоже, на, то]',
#  '[тебе, удачи, на, экзе]',
#  '[да, у, меня, была, темпа, 15, дня, сейчас, горло, тревожит, а, в, остальном, бодрячком]',
#  '[дааа, сейчас, с, этим, жопа]',
#  '[может, он, непонятый, гений]',
#  '[а, ты, не, знаешь, почему, в, моей, игрушке, слово, читер, запрещенное, слово]',
#  '[не, я, раньше, много, играла]',
#  '[типа, фортнайта]',
#  '[и, там, в, чате, запрещено, слово, читер, по-моему]',
#  '[его, нельзя, написатт]',
#  '[о, мой, бог]',
#  '[аа, меня, обижают, спидаки, что, делать]',
#  '[нечестно, получается]',
#  '[это, где, такое]',
#  '[и, как, обидеть]',
#  '[больше, ни, во, что]',
#  '[я, месяца, два, назад, неожиданно, правилась, с, зависимостью, к, играм]',
#  '[желание, просто, пропала]',
#  '[несколько, лет, не, пропадало]',
#  '[и, тут, вот, тебе, на]',
#  '[само, собой]',
#  '[только, англ]',
#  '[еще, есть, фр, и, нем]',
#  '[но, я, выбрала, англ]',
#  '[с++, джава, в, следющем, семестре, питон]',
#  '[самые, основные]',
#  '[полина, узнала, через, знакомых, какие, языки, сейчас, нужны]',
#  '[вот, эти, три, и, назвала]',
#  '[только, нас, так, учат…]',
#  '[работы, дают, и, проверяют, остальное, сам]',
#  '[типо, сложно, по, сути, самообучение, но, под, присмотром]',
#  '[но, в, этом, году, по, джаве, препод, был, хороший, жаль, что, я, не, ходила]',
#  '[да, мне, кажется, что, языки, не, особая, проблема, выучить, можно, за, пару, месяцев, один, есди, прям, ботать]',
#  '[ну, у, меня, сопли, пока, тусуюсь, дома, экз, скоро]',
#  '[пока, результатов, нет]',
#  '[ты, напиши, в, беседу, потока, пусть, поднапрягутся]',
#  '[тебя, не, только, группа, не, любить, будет]',
#  '[но, и, весь, поток]',
#  '[представь, какой, масштаб]',
#  '[не, хиханьки, да, хаханьки, уже, будет]',
#  '[да, я, поняла]',
#  '[он, спас, всю, группу, ценой, своей, жизни]',
#  '[не, повезло, челу, по, всем, пунктам]',
#  '[люди, извращенцы]',
#  '[да, я, иногда, расстраиваюсь, из-за, перевода]',
#  '[а, в, чем, прикол]',
#  '[связано, с, никой]',
#  '[так, стало, понятно]',
#  '[я, не, видела, приношу, свои, свои, извинения, за, игнор]',
#  '[напомни, тебе, рассказать, про, трипофобию]',
#  '[кое-что, поинтереснее]',
#  '[я, ночью, проверю]',
#  '[вообще, должен, был]',
#  '[сделаем, ставки]',
#  '[кому, дарит, сережа]',
#  '[так, нечестно]',
#  '[значит, для, тебя, не, сектор, приз]',
#  '[мне, скажешь]',
#  '[ну, марк]',
#  '[у, меня, твой, джул]',
#  '[господи, безумие, какое-то]',
#  '[даже, не, знаю, как, это, выглядит]',
#  '[или, у, тебя, в, процессе, чего-то, сломался]',
#  '[не, стану]',
#  '[ничего, не, поняла]',
#  '[метери, кожухе]',
#  '[вот, чего, ты, все, время, туда, лезешь]',
#  '[уже, ведь, была, история]',
#  '[ты, сказал, что, побьешь, себя]',
#  '[если, еще, раз, чего-то, там]',
#  '[можешь, бить]',
#  '[боже, мой]',
#  '[и, как, до, тебя, дошло]',
#  '[типо, радиус, уменьшился]',
#  '[у, блютуза]',
#  '[сам, бог, смеется]',
#  '[над, марком, хаустовым]',
#  '[ничему, тебя, жизнь, не, учит]',
#  '[а, дорого, новый, стоит]',
#  '[чтобы, заменить]',
#  '[или, тебе, нет, особый, нужды]',
#  '[напиши, мне, завтра, в, часика, 4, про, джул, на, всякий, случай]',
#  '[ты, же, пьяный]',
#  '[ты, че, творишь, вообще]',
#  '[иди, спать]',
#  '[сейчас, же]',
#  '[лучше, завтра]',
#  '[утро, вечера, мудренее]',
#  '[просто, ты, сейчас, можешь, быть, менее, осторжным, и, ловким]',
#  '[лучше, реально, поспать]',
#  '[сладких, снов, марк]',
#  '[нечего, было, вносить, корректировки, в, комп]',
#  '[этот, чел, ебанутый]',
#  '[я, с, ним, на, съемках, была, как-то]',
#  '[с, малолетними, девочками, флиртовал]',
#  '[кто-то, говорил, что, у, него, кучу, скандалов, по, поводу, сексуальных, наклонностей]',
#  '[а, почему, ты, один, говоришь, что, пойдешь, тогда]',
#  '[все-таки, нет]',
#  '[я, устала]',
#  '[как, штирлец, связан, с, тук, тук]',
#  '[я, поняла]',
#  '[как, с, этим, штрилец, связан]',
#  '[в, дверь]',
#  '[по, голове]',
#  '[блин, надо, глянуть, фильм]',
#  '[по, пн, в, powerhouse, jazz, jam, с, 8, часов, вечера]',
#  '[хочешь, пойти, виз, ми]',
#  '[этот, jazz, jam, только, по, пн]',
#  '[вход, свободный]',
#  '[искала, другие, места]',
#  '[но, во, многих, по, билетам]',
#  '[я, хотела, в, этот, пн, пойти]',
#  '[марк, а, точно, идем]',
#  '[можно, и, без, брлни, прийти]',
#  '[если, ты, можешь, то, было, здорово]',
#  '[у, меня, бабушка, приехала]',
#  '[я, тут, бегаю, и, пляшу]',
#  '[так, идем]',
#  '[просто, нас, только, двое]',
#  '[и, не, факт, что, там, много, людей, будет]',
#  '[да, и, прикольная, штука]',
#  '[хочу, сходить]',
#  '[это, на, таганке]',
#  '[сам, джаз, джем, начнётся, в, 8]',
#  '[но, мы, можем, как, раньше, так, и, позже]',
#  '[паспорт, не, забудь]',
#  '[давай, встретимся, в, 730, на, таганке]',
#  '[и, если, можешь, возьми, повербенк, пжл]',
#  '[уже, там]',
#  '[если, хочешь]',
#  '[как, тебе, удобно]',
#  '[я, сейчас, в, автобусе]',
#  '[который, идет, до, киевской]',
#  '[так, что, не, могу, точно, сказать]',
#  '[полагаю, что, к, назначенному, времени]',
#  '[там, по-моему, несколько, залов, так, что, надо, еще, понять, куда, сесть]',
#  '[или, откроется, зал, с, джазом]',
#  '[что, откроется]',
#  '[это, не, стеб, я, реально, не, понимаю]',
#  '[там, симпатично]',
#  '[я, выхожу, из, автобуса]',
#  '[и, залетаю, в, метро]',
#  '[там, пишут, 12, мин, ехать]',
#  '[11, минут]',
#  '[а, как, ты, шел]',
#  '[типо, не, ощутил, время]',
#  '[уууу, понимаю]',
#  '[хотя, нет]',
#  '[я, велосипедов, не, замечаю]',
#  '[опасно, доя, жизни]',
#  '[я, потеряла, б]',
#  '[я, внутри]',
#  '[куда, дальше]',
#  '[а, дальше]',
#  '[взгляните, на, это…, 👀\\\\n, link, https//pinit/1lwjzid]',
#  '[у, меня, вопрос, вк, тебя, напрягает, из-за, того, что, он, несекретный, или, в, чем, прикол]',
#  '[всё-таки, хотят, уже]',
#  '[но, мне, от, этого, как-то, никак]',
#  '[а, до, этого, не, могла]',
#  '[вот, это, точно, могла]',
#  '[ну, работать, да]',
#  '[я, думала]',
#  '[что, они, к, чему-то, более, конкретному, придут]',
#  '[да, просто, уже, были, такие, переговоры]',
#  '[ни, к, чему, они, не, привели]',
#  '[оу, фак]',
#  '[я, теперь, тоже, себе, такой, хочу]',
#  '[ты, пробовал, рисовать]',
#  '[да, норм, все]',
#  '[как, есть]',
#  '[хочу, тоже, такое]',
#  '[нет, у, нас, такого, не, было]',
#  '[первый, о, ком, я, подумала, был, каркарыч, но, после, ее, аргументов, передумала]',
#  '[реальность, все, с, какими-то, тараканами]',
#  '[а, ты]',
#  '[она, паникер]',
#  '[и, мамочка]',
#  '[если, соглашаться, на, тараканов]',
#  '[то, он]',
#  '[самый, разумный, хомосапиенс]',
#  '[хитрость, порождена, высоким, интеллектом, и, способностью, анализировать]',
#  '[ну, а, совунья, в, облаках, жила]',
#  '[хочу, глянуть, серию, с, двойником, лосяша]',
#  '[нет, ее, туда, запульнули, и, она, не, моогла, спуститься]',
#  '[серия, невоспитанный, клон]',
#  '[случайно, нет]',
#  '[ну, у, сестры, есть, понятное, дело]',
#  '[а, все, что, ли]',
#  '[нельзя, будет]',
#  '[он, же, просто, офис, закрыл]',
#  '[а, работать, будет]',
#  '[в, чем, прикол]',
#  '[у, меня, тоже, спотифай]',
#  '[подожди, я, пытаюст, найти, инфу, по, поводу, этого]',
#  '[я, тоже, тут, читала]',
#  '[а, если, сестру, просить, то, как, оно, будет, сниматься, тут, рубли, а, у, нее, другие, валюты, дороже, будет, в, разы, да]',
#  '[если, я, слечу, с, подписки, то, у, меня, уже, не, будет, избранной, музыки, и, исчезнет, моя, сохраненная, музыка, реклама, будет]',
#  '[по-моему, исчезнет, даже, то, что, ты, сейчас, лайкнул, когда, подписка, вернется, то, и, вернется, то, что, ты, лайкнул]',
#  '[короче, похуй, я, буду, в, телеге, музыку, слушать]',
#  '[у, меня, летом, не, было, подписки, еще, на, спотифай]',
#  '[и, моя, сестра, подсказала, что, в, телеге, есть, боты, которые, ищут, нужные, треки, и, скачивают, их]',
#  '[соответственно, их, можно, слушать, без, интернета]',
#  '[я, не, знаю, что, для, тебя, важнее, всего]',
#  '[мне, главное, отсутсвие, рекламы]',
#  '[и, без, интернета, иногда, нужно]',
#  '[в, метро, не, всегда, ловит]',
#  '[бляяяяяяя, нееет]',
#  '[это, типо, дорого]',
#  '[литр, бензина, в, италии, стоит, 224, евро]',
#  '[короче, ботов, можно, поискать, в, телеге, они, есть, рабочие, но, их, частенько, блокируют…]',
#  '[ты, не, рад]',
#  '[должна, же, быть, причина]',
#  '[это, какое-то, научный, термин, или, ты, придумал, и, what, do, you, mean]',
#  '[красивая, собака]',
#  '[другая, на, улице]',
#  '[потом, узнаю, что, это]',
#  '[не, торопи, событи]',
#  '[у, меня, спотифай, вылетел]',
#  '[у, тебя]',
#  '[пошли, нахуй, все]',
#  '[дискорд, тоже…]',
#  '[или, с, россией]',
#  '[смотря, какой]',
#  '[может, для, меня, это, не, важно]',
#  '[это, намек]',
#  '[хочешь, укр, паспорт]',
#  '[папа, сказал, я, бы, на, твоем, месте, задумался]',
#  '[мне, какая, польза, статус, мой, муж, марк, хаустов]',
#  '[зная, тебя, ты, будешь, скрывать, часть, дохода]',
#  '[я, не, замечала, обмана, в, мой, адрес]',
#  '[надеюсь, ты, не, погубишь, мое, доверие]',
#  '[иначе, вот, так, будет, с, тобой]',
#  '[короче, если, что]',
#  '[ты, первый, в, очереди]',
#  '[я, знаю, что, украинцы, понимают, белорусский, и, наоборот]',
#  '[на, русский, тоже, похоже, очень]',
#  '[вот, вот]',
#  '[местами, просто, слова, кардинально, отличаются]',
#  '[ты, как, всегда]',
#  '[просто, пришла, пожелать, тебе, спокойной, ночи]',
#  '[я, недавно, думала, почему, коммунизм, это, плохо]',
#  '[надо, почекать, инфу]',
#  '[немного, ленина, в, голову, стукнуло]',
#  '[не, не, я, посмотрю, видео]',
#  '[потому, что, мне, непонятно]',
#  '[да, не]',
#  '[типо, сссрver2]',
#  '[я, в, такое, не, поверю]',
#  '[ожидаемо, в, принципе]',
#  '[впн, нужен]',
#  '[у, тебя, конечно, не, айос]',
#  '[но, мб, посоветуешь, что-то]',
#  '[а, можно, на, двух, устройствах]',
#  '[это, для, компа, или, тел]',
#  '[сейчас, попробую]',
#  '[сколько, ты, платишь🤔]',
#  '[или, это, окей, для, впн]',
#  '[мое, уважение]',
#  '[мне, сейсас, стало, страшно, что, там, без, входа, и, уч, запись, берется, автоматически, запись, эпл]',
#  '[кто, не, рискует, тот, не, пьет]',
#  '[а, ты, будешь, в, инсте, сидеть]',
#  '[или, тебе, пофиг]',
#  '[а, потом, в, даркнет, залететь]',
#  '[интересно, происходящее, же, повлияло, на, дилеров]',
#  '[о, как]',
#  '[так, а, еще, вопрос]',
#  '[у, меня, завтра, подписка, выходит, на, спотифай]',
#  '[сестра, сама, предложила, продлить]',
#  '[короче, как, думаешь, сколько, накинется, на, оплату]',
#  '[с, укр, карточки]',
#  '[в, рубли]',
#  '[так, дороже, вроде¿]',
#  '[ты, для, себя, хочешь]',
#  '[да, только, деньги, не, мне, нужны, а, им]',
#  '[ща, я, буду, думать]',
#  '[так, продолжай]',
#  '[я, просто, в, этом, ноль]',
#  '[вроде, получилось]',
#  '[завтра, еще, проверим]',
#  '[карту, нельзя, изменить, в, спотифай]',
#  '[а, саундклауд, работает]',
#  '[туда, можно, перекинуть, автоматом, все, плейлисты, и, избранные]',
#  '[сейчас, пробую]',
#  '[никогда, не, пользовалась, саунд, клаудом]',
#  '[там, окей]',
#  '[не, я, прям, сейчас, пробую, это, сделать]',
#  '[какой-то, сайт]',
#  '[надеюсь, данные, не, спиздят]',
#  '[что, это, значит]',
#  '[не, похоже, на, санитаров]',
#  '[а, что, он, делал]',
#  '[а, что, это, значит]',
#  '[для, меня, это, ни, о, чем, не, говорит]',
#  '[просто, для, меня, эти, личности, конкретно, непонятны, к, сожалению]',
#  '[ничего, о, них, не, знаю]',
#  '[как, тебе]',
#  '[bold, сила, в, правде, за, победу\\\\n, в, продаже, с, 22, марта]',
#  '[подпишись, на, канал, и, поставь, лайк]',
#  '[такие, приколы, мне, нравятся]',
#  '[в, смысле]',
#  '[почему, забрали]',
#  '[сегодня, я, задалась, вопросом, почему, ты, мне, не, пишешь]',
#  '[а, вот, в, вк, есть, защита, от, чсв]',
#  '[а, мама, что]',
#  '[какого, хрена, забрали]',
#  '[а, тебе, ок, без, них]',
#  '[видимо, творческий, кризис]',
#  '[ты, не, согласился]',
#  '[я, поэтому, и, не, подписалась]',
#  '[не, ну, а, что]',
#  '[ты, звонил]',
#  '[а, тебе, дадут, рабочую, визу]',
#  '[или, в, рашке]',
#  '[я, даже, не, знаю, что, это]',
#  '[а, конкретнее, можно]',
#  '[вообще, именно, такого, названия, дисциплины, не, было]',
#  '[но, мб, что-то, похожее, было]',
#  '[сейчас, бегу, в, туалет]',
#  '[ты, тоже]',
#  '[это, на, выпускной]',
#  '[есть, два, вопроса]',
#  '[а, модет, и, больше]',
#  '[ты, общаешься, с, ваней]',
#  '[ты, бы, хотел, погулять, втроем]',
#  '[такое, трио, кайфовое, прям, было, ьы]',
#  '[благодаря, вам]',
#  '[там, еще, вопрос, будет]',
#  '[жду, ответик]',
#  '[ты, че, выходишь]',
#  '[это, алена]',
#  '[третий, вопрос]',
#  '[а, ваня, захотел, бы]',
#  '[или, лучше, у, него, спрашиватт]',
#  '[я, не, знаю, куда]',
#  '[но, идея, с, баром, не, супер, привлекательна]',
#  '[ну, это, второй, вопрос]',
#  '[пойдем, ли, мы, куда-то]',
#  '[а, я, в, геншин, начала, играть]',
#  '[этот, с, тотушкой]',
#  '[ты, спросил]',
#  '[то, есть, ответ, нет]',
#  '[марк, помнишь, ты, мне, недавно, звонил, ты, реально, случайно, позвонил]',
#  '[или, что-то, произошло]',
#  '[да, просто, потом, мысли, дурные, настигли]',
#  '[у, меня, пять, выпало]',
#  '[а, у, тебя, скока, будет]',
#  '[1, у, тебя]',
#  '[так, можно, споры, в, телеге, решать]',
#  '[я, вообще-то]',
#  '[у, меня, больше]',
#  '[у, меня, только, 4…]',
#  '[на, удивление, эта, пара, получилась, тютелька, в, тютельку]',
#  '[мне, дали, 4, очка]',
#  '[у, даши, 51…]',
#  '[она, сотку, хочет]',
#  '[со, второго, раза, блять]',
#  '[я, видела]',
#  '[где, слушать, музыку]',
#  '[там, миксы]',
#  '[в, основном]',
#  '[вк, походу, остаётся]',
#  '[что, фу]',
#  '[на, войне, все, средства, хороши]',
#  '[bold, top, players, \\\\n1, марк, bold, 805, \\\\n2, liza, bold, 703]',
#  '[у, меня, пара, с, душной, преподшей]',
#  '[она, нацистка]',
#  '[и, не, только]',
#  '[она, очень, стара, в, своих, мыслях]',
#  '[савок, чисто]',
#  '[bold, top, players, \\\\n1, марк, bold, 1564, \\\\n2, liza, bold, 645]',
#  '[а, против, войны, слышал]',
#  '[просто, могут, не, говорить]',
#  '[погнали, в, субботу, в, эту]',
#  '[втроем, если, получится]',
#  '[когда, сможешь, дать, ответ]',
#  '[ну, вообще, это, время, подходит]',
#  '[а, ты, как]',
#  '[после, пар, ок, будет]',
#  '[я, даже, не, знаю]',
#  '[погода, позволяет, погулять]',
#  '[идем, гулять]',
#  '[на, удицу]',
#  '[давай, станцию, выберем]',
#  '[и, там, встретимся]',
#  '[во, сколько, получается]',
#  '[оки, доки]',
#  '[ване, напишешь, да]',
#  '[ты, лучший]',
#  '[и, что, это]',
#  '[тебе, повезло]',
#  '[я, не, сплб]',
#  '[это, все]',
#  '[доброй, ночи]',
#  '[по, факту]',
#  '[у, нас, в, экзаменах, такие, вопросы, есть]',
#  '[и, их, через, прогу, проверяют]',
#  '[а, не, хуйней, страдают]',
#  '[еще, и, цвета, можно, выбрать]',
#  '[ты, стал, мухомором]',
#  '[я, прочитала, зависть…]',
#  '[по, фрейду]',
#  '[откуда, у, тебя]',
#  '[типо, булгаков]',
#  '[алвингов, такого, не, знаю]',
#  '[выглядит, круто]',
#  '[ты, можешь, помочь, найти, мне, трек]',
#  '[у, меня, не, получается]',
#  '[link, https//soundcloudappgoogl/usgrflzctriw29yf9]',
#  '[объясни, пжл, как]',
#  '[они, потеряли]',
#  '[что, это, вообще, такое]',
#  '[как, ты, умудрился, этим, повредить, руку]',
#  '[а, еще]',
#  '[мне, тоже, очень, нравится, твет, давай, если, будет, концерт, пойдем, туда]',
#  '[он, сейчас, их, отменил, но, вдруг]',
#  '[потому, что, я, не, понимаю, то, что, ты, кидаешь]',
#  '[но, вот, это, к, примеру]',
#  '[набор, слов]',
#  '[ну, ладно, не, набор, слов]',
#  '[но, про, какую, русскую, идею, идет, речь]',
#  '[мб, у, него, с, математикой, туго]',
#  '[я, не, пониматт]',
#  '[дерьмое, приложение]',
#  '[иди, в, чемприкол]',
#  '[неее, у, меня, не, было, такого]',
#  '[я, в, детстве, музыку, не, слушала]',
#  '[ну, точнее, музыка, сестры, играла, мне, этого, было, достаточно]',
#  '[все, уже]',
#  '[у, меня, было, красивл]',
#  '[а, ты, что, наделал]',
#  '[так, почему, обратно, не, поменят]',
#  '[неее, если, бы, было, так, я, бы, тебя, заблокала]',
#  '[не, знаю, не, знаю]',
#  '[если, вы, все, еще, не, разобрались, как, продлить, подписку, на, spotify, то, вам, помогут, вот, text_link, эти, ребята, href, https//podpiskaorg/spotify/utm_source=telegram, &, utm_medium=cpm, &, utm_campaign=myidem, &, utm_term=april, они, подключат, ваш, аккаунт, к, семейной, премиум-подписке, так, что, вся, медиатека, останется, на, месте, инструкцию, ищите, по, ссылке, выше\\\\n\\\\nвсе, работает, четко, подписки, есть, на, 6, и, 12, месяцев, а, еще, они, же, могут, вам, помочь, и, с, text_link, подпиской, на, netflix, href, https//podpiskaorg/netflix/utm_source=telegram, &, utm_medium=cpm, &, utm_campaign=myidem, &, utm_term=april]',
#  '[ты, как, всегда]',
#  '[а, я, не, поняла]',
#  '[спотифай, работает]',
#  '[без, впн]',
#  '[а, что, за, ограничения, цб]',
#  '[такое, мне, оч, нравится]',
#  '[сколько, тебя, стригли, блять]',
#  '[ты, уверен]',
#  '[а, фотка, есть]',
#  '[а, че, не, так]',
#  '[ты, часто, придираешься]',
#  '[что, в, этот, раз, тоже]',
#  '[в, любом, случае, отрастет]',
#  '[не, представляю, тебя, с, таким]',
#  '[сейчас, тебе, красиво]',
#  '[с, такой, прической]',
#  '[оу, фак]',
#  '[до, осени, еще, дожить, надр]',
#  '[еще, бы, знать, что, это]',
#  '[ща, гляну]',
#  '[мне, не, зашло]',
#  '[я, такого, не, знаю]',
#  '[до, 28, мая, время, есть]',
#  '[гляну, его]',
#  '[ты, ее, выгуливаешь¿]',
#  '[но, зачем]',
#  '[и, ты, падаешь]',
#  '[а, как, зовут]',
#  '[я, буду, звать, тебя, человеком]',
#  '[у, тебя, расистские, наклонности]',
#  '[марк, ты, от, какой, станции, будешь, шагать]',
#  '[все, я, тебе, больше, не, нужна]',
#  '[не, особо, ошибся]',
#  '[это, эпл]',
#  '[у, меня, такое, чувство, что, вы, мне, с, дашей, не, дорассказали, ваши, падения, за, зиму]',
#  '[ты, в, джинсовке, что, ли, ходишь]',
#  '[я, же, спрашивала, и, гвоорила, что, веду, счетчик, падений]',
#  '[падал, вообще-то]',
#  '[все, задокументировано]',
#  '[не, помню]',
#  '[надеюсь, не, только, физические]',
#  '[какой, ты]',
#  '[это, как]',
#  '[а, что, надо, делать]',
#  '[надо, напиться]',
#  '[или, что]',
#  '[как, так]',
#  '[такое, сложно, забыть]',
#  '[ах, ты, сука]',
#  '[до, сих, пор, не, прочитал]',
#  '[ты, меня, заблокал, что, ли]',
#  '[раз, не, доставлено]',
#  '[ладно, думаю, что, не, заблокал…, надеюсь…]',
#  '[пройди, тест, на, тип, привязанности]',
#  '[хватит, спать]',
#  '[link, https//wwwidrlabscom/ru/attachment-style/testphp]',
#  '[к, другим, людям]',
#  '[я, думаю, что, уловил, в, процессе, суть]',
#  '[сидела, я, делала, просроченное, задание, на, гите, не, работала, какая-то, функция, которая, есть, на, линуксе, но, не, на, винде, больше, я, это, не, делала]',
#  '[смотрел, очень, странные, дела]',
#  '[у, меня, все, ок, было]',
#  '[хотела, растянуть, сезон]',
#  '[посмотрела, серию, в, один, день]',
#  '[остальной, сезон, в, другой]',
#  '[мне, не, супер, зашли, спецэффекты, нереалистичные, местами, прям, сильно]',
#  '[тут, дофига, русских, хотя, ты, и, сам, я, лумаю, в, курсе]',
#  '[но, местами, русские, совершенно, не, русские]',
#  '[но, не, специально, как-то, вышло]',
#  '[но, не, каждый, второй, марк]',
#  '[так, что, не, справедливо]',
#  '[у, меня, до, 2, числа]',
#  '[пиздец, правда]',
#  '[до, 2, июля]',
#  '[у, тебя]',
#  '[ну, так, норм]',
#  '[а, когда, доп, день]',
#  '[для, сдачи]',
#  '[это, да]',
#  '[резервный, денб]',
#  '[если, что-то, не, сдал, по, разным, причинам]',
#  '[есть, один, день, в, конце, сессии, когда, можно, сдать, один, экз]',
#  '[и, это, не, будет, пересдачей, считаться]',
#  '[будем, по, рации, общаться]',
#  '[судя, по, тому, что, ты, мне, это, скинул, ты, дочитал, до, конца, я, в, шоке]',
#  '[что, вообще, просиходит]',
#  '[это, акне]',
#  '[я, сегодня, не, красилась, особо]',
#  '[хотелось, побыстрее, сдать]',
#  '[тебе, то, зачем]',
#  '[у, тебя, все, круто]',
#  '[а, ты, умывалками, хорошими, пользуешься]',
#  '[это, на, даче, такой, вид]',
#  '[ты, айфон, купил]',
#  '[я, не, видела]',
#  '[у, него, есть, телеграмм]',
#  '[какой, мед]',
#  '[а, там, будешь, искать, себя, в, разных, сферах]',
#  '[хотя, если, пойти, в, какую-то, научную, сферу, тебе]',
#  '[вот, это, да, твоей, голове, это, пошло, бы]',
#  '[та, да]',
#  '[многовато, как-то]',
#  '[как, умно, с, твоей, стоооны]',
#  '[мейби, бейби]',
#  '[не, умирай, пжл]',
#  '[я, тебя, задела]',
#  '[теперь, уже, и, ты, кислотный]',
#  '[давишь, прям]',
#  '[почему, в, этот, раз]',
#  '[что, происходит]',
#  '[ты, ввел, меня, в, ступор]',
#  '[я, не, понимаю]',
#  '[как, ты, можешь, вычислить, мою, личность]',
#  '[по, такому, вопросу]',
#  '[тогда, нет]',
#  '[я, не, динозавр]',
#  '[я, смотрю, в, будущее]',
#  '[дикий, прикол, какой-то]',
#  '[а, разве, не, могу]',
#  '[это, не, мунк]',
#  '[но, мейби, бейби]',
#  '[реально, оттуда, как, будто, взято]',
#  '[я, нарисовала]',
#  '[но, это, я, рисовала, на, паре, по, экономике]',
#  '[а, там, преподша, такая, блять, нацистка]',
#  '[что, да]',
#  '[да, и, только]',
#  '[подписка, нетфликм]',
#  '[или, что]',
#  '[с, каким, это]',
#  '[у, тебя, задержка, на, два, час]',
#  '[да, она, не, глупая, женщина]',
#  '[не, думаю, что, в, этом, проблема]',
#  '[я, даже, на, гитхабе, ничего, не, постила]',
#  '[хотя, должна, была]',
#  '[вот, ду, ю, мин]',
#  '[я, часов, 6, назад, пила, водку]',
#  '[мне, хуево]',
#  '[да, блин]',
#  '[еще, и, жара]',
#  '[вообще, жопа]',
#  '[что, с, аней, вообще, творится]',
#  '[я, думаю]',
#  '[что, они, подходят, друг, другу]',
#  '[вот, и, все]',
#  '[еще, синячки, можно, было]',
#  '[уважаю, такой, ответ]',
#  '[это, кто, там, такой]',
#  '[4, гб…]',
#  '[купи, уже, себе]',
#  '[а, вышло, хорошо]',
#  '[пока, скачивать, не, буду]',
#  '[мне, не, нравится, конкретно, образ, алисы]',
#  '[ковёр, пиздатый]',
#  '[наша, реальность, тебе, не, нравится]',
#  '[ну, тут, согласна]',
#  '[это, что, такое]',
#  '[что, за, программа]',
#  '[у, меня, сейчас, нет, на, это, денег]',
#  '[да, сделай, уже, себе]',
#  '[я, до, сих, пор, оч, хочу]',
#  '[но, денег, нема]',
#  '[хотя, были]',
#  '[окей, тогда, я, вернусь, с, моря, и, займусь, активно, этим, вопросом]',
#  '[найди, тогда, студию]',
#  '[и, мастера, которые, тебе, заходят]',
#  '[а, я, поищу, для, себя]',
#  '[та, девушка, улетела, по-моему]',
#  '[да, и, хотелось, бы, дешевле, чем, у, нее]',
#  '[сначала, надо, стать, популярным]',
#  '[давай, я, тебе, сотку, скину]',
#  '[кому, рф]',
#  '[не, знаю]',
#  '[на, 7, больше]',
#  '[всего, лишь]',
#  '[лобстеры, конечно]',
#  '[сложно, для, понимания]',
#  '[это, я, к, счастью, знаю]',
#  '[клоун, теперь, премиум]',
#  '[он, реально, так, сказал]',
#  '[или, это, шутка]',
#  '[это, еще, зачем]',
#  '[выдавливали, что, ли]',
#  '[жж, это, кто]',
#  '[29, июля, в, доме, культур, пройдет, text_link, образцовая, диско-вечеринка, href, https//wwwinstagramcom/p/cfvstqhlwok, от, команды, a, casa, ребята, превратят, локацию, в, рай, для, сладкоежек, с, сахарной, ватой, и, коктейлями, а, еще, поставят, вагончик, с, мороженым, как, из, детства\\\\n\\\\nглавные, гостьи, тусовки, опытная, виниловая, диггерша, karolina, bnv, и, whiez, из, комьюнити, sk8techno, с, грувовой, селекцией, поддержат, артисток, постоянные, резиденты, команды, julia, konor, discopank, и, wezego, с, отборной, подборкой, всех, оттенков, диско-музыки\\\\n\\\\nкупить, билеты, можно, text_link, по, ссылке, href, https//acasamusictimepadru/event/2099695/, с, промокодом, myidem, вы, получите, скидку, 20, %]',
#  '[не, хочу]',
#  '[пса, жаль]',
#  '[я, вечером, деньги, кину]',
#  '[я, опять, с, налом, хожу]',
#  '[не, забудь]',
#  '[про, промокод]',
#  '[напиши, сколько, надо, скинуть, потом]',
#  '[какие-то, планы, в, субботу]',
#  '[зависит, от, того]',
#  '[насколько, классно, будет]',
#  '[типо, по, ситуации, смотреть, буду]',
#  '[сколько, по, итогу]',
#  '[700-20, %]',
#  '[а, како, юанк]',
#  '[тебе, спасибо]',
#  '[да, не, извиняйся]',
#  '[это, как, бы, твое, дело]',
#  '[ну, ты, туда, на, час, залетишь, или, до, скольки, приблизительно]',
#  '[думаю, что, переживу]',
#  '[метро, в, час]',
#  '[насчет, бара]',
#  '[позже, спишемся]',
#  '[давай, в, 9]',
#  '[это, на, китай-городе]',
#  '[а, в, чем, идти]',
#  '[марк, а, у, тебя, есть, какая-нибудь, сумка, через, плечо, аля, спортивная, мне, дать]',
#  '[типо, ты, будешь, в, ней]',
#  '[а, еще]',
#  '[затянулась, ашкой]',
#  '[а, она, продолжила, работать]',
#  '[из-за, чего, может, быть, не, знаешь]',
#  '[вот, я, затягиваюсь, огонек, загорается, и, продолжает, гореть, будто, я, тяну, еще]',
#  '[один, раз, было]',
#  '[потом, все, ок]',
#  '[насчет, сумки]',
#  '[я, нашла, у, себя]',
#  '[плюс, минус, удобную]',
#  '[а, насчет, ашки]',
#  '[это, пиздец]',
#  '[я, ее, обрезала]',
#  '[она, перестала, выключатся]',
#  '[надеюст, что, не, взорвется]',
#  '[мне, неудобно, говорить]',
#  '[ты, уже, там]',
#  '[и, что, делать, будем]',
#  '[какие, еще, варианты, есть]',
#  '[я, знаю, бир, енд, фрайс]',
#  '[но, там, тоже, много, будет, скорее, всего]',
#  '[прям, совсем, некуда]',
#  '[я, от, площади, революции]',
#  '[но, я, опаздываю]',
#  '[на, славянке, только]',
#  '[а, может, лучше]',
#  '[еще, в, бары, заглянешь]',
#  '[а, название]',
#  '[может, лучше, в, пестики]',
#  '[хотелось, дожить, до, завтра]',
#  '[ну, ок]',
#  '[я, шагаю]',
#  '[ты, где]',
#  '[не, вижу]',
#  '[может, я, не, там]',
#  '[значит, название, не, то]',
#  '[я, в, этот, пришла]',
#  '[тут, еще, диджей, сет]',
#  '[тут, круто]',
#  '[и, мест, дофига]',
#  '[where, r, u]',
#  '[я, дома, все, хорошо]',
#  '[я, вообще, не, в, восторге]',
#  '[а, мой, пиджак, тебе, не, подойдет, вхаххахахха]',
#  '[вообще, черный, пиджак]',
#  '[это, стиль]',
#  '[мне, нравится, на, парнях]',
#  '[но, он, оверсайзный, так, то]',
#  '[на, мне, так, точно]',
#  '[что, за, прикол, с, женским, и, мужским, стаканом]',
#  '[если, они, планировали, сделать, такое]',
#  '[то, как, минимум, мне, непонятно, это, разделение]',
#  '[но, учиться, за, границей, можно, много, еще, где, \\\\n\\\\nи, учеба, сейчас, это, самый, простой, способ, эмиграции, на, карте, можно, увидеть, где, есть, полное, покрытие, расходов\\\\n\\\\nпо, дедлайнам, сейчас, можно, успеть, податься, на, следующие, гранты, которые, полностью, покрывают, daad, германия, erasmus, mundus, европа, hungaricum, stipendium, венгрия, visby, швеция, gks, южная, корея, и, поступить, весной/осенью, 2023\\\\n\\\\n🇬🇷еще, сейчас, есть, вариант, поступить, на, языковые, курсы, в, греции, после, которых, можно, учиться, там, бесплатно, на, греческом\\\\n\\\\nчтобы, увеличить, шансы, лучше, использовать, проверенные, маршруты, ребята, из, univibes, помогают, с, документами, сопровождают, на, всем, пути, а, так, как, кураторы, уже, выигрывали, эти, гранты, они, знают, как, это, делать\\\\n\\\\nеще, у, них, можно, купить, гайд, по, всем, стипендиям, получить, первую, бесплатную, консультацию, оценить, свои, шансы, подобрать, программу, в, общем, если, не, хватает, импульса, то, вот, он, промокод, на, 7, %, cкидки, -, mishapetrow\\\\n\\\\nих, text_link, телеграм, канал, href, https//tme/univibes, c, грантами, подписывайтесь\\\\n\\\\nкто, сейчас, куда, поступает, рассказывайте]',
#  '[да, понятное, дело]',
#  '[я, сейчас, рентген, делала]',
#  '[мне, сказали, что, у, меня, чистые, легкие]',
#  '[спросили, курю, ли, я]',
#  '[может, реально, все, хорошо]',
#  '[гражданство, буду, делать]',
#  '[вот, это, у, меня, давление, и, скачет, обмороки, и, кровь, носом]',
#  '[у, меня, в, октябре, внутренний, паспорт, станет, просроченным]',
#  '[я, туда, не, поеду]',
#  '[в, украине, жить, не, планирую]',
#  '[тем, более, украинский, паспорт, у, меня, никто, не, заберет]',
#  '[пока, нет]',
#  '[эти, года, не, требовали]',
#  '[такой, пушистый]',
#  '[я, думала, что, ты, его, загубишь]',
#  '[я, думала, что, они, просто, языками, чешут]',
#  '[пока, не, факт, что, примут]',
#  '[и, там, же, многие, страны, за, мир]',
#  '[так, что, не, думаю]',
#  '[что, это, случится]',
#  '[я, хочу, на, тебя, пожаловаться]',
#  '[я, прошлой, ночью, глядела, на, свою, косметику, и, вспомнила, твой, заскок, когда, ты, все, оттираешь, от, грязи, теперь, вся, моя, косметика, чистая]',
#  '[и, если, можно, нет, ли, каких-то, проблем, с, этим]',
#  '[может, и, есть]',
#  '[а, есть, какая-то, разница]',
#  '[есть, карта, немецкого, банка, но, она, для, соцвыплат, лучше, с, неё, никаких, операций, не, проводить, я, могу, отдельную, карту, открыть, в, немецком, банке, в, евро, ещё, я, жду, доставку, карты, binance, пластиковую, карту, я, имею, ввиду]',
#  '[в, плане]',
#  '[нужно, положить, деньги, в, россии, и, снять, в, германии]',
#  '[мы, не, идём]',
#  '[мы, лиза, и, даша]',
#  '[пока, нет]',
#  '[не, писали]',
#  '[грустно, это]',
#  '[а, что, ты, написал]',
#  '[мы, с, дашей, болеем]',
#  '[придумать, что-то, еще]',
#  '[да, зачем, оправдываться]',
#  '[более, того, это, ctrl, c, -, ctrl, v]',
#  '[марк, меняй, аву]',
#  '[сейчас, прям]',
#  '[не, знаю]',
#  '[на, что, нравится]',
#  '[да, мне, он, так, и, не, нужен]',
#  '[это, сестра, что-то, пытается]',
#  '[но, я, хочу, изучить, немного, всю, эту, тему]',
#  '[хоть, немного, понимать]',
#  '[но, деньги, хотелось, бы, закинуть]',
#  '[тогда, если, купишь]',
#  '[опять, мухомор]',
#  '[поставь, тогда, реальный, мухомор]',
#  '[зато, интересно]',
#  '[если, честно]',
#  '[думаю, что, ты, бы, его, не, съел]',
#  '[удобнее, его, кому-то, подсунуть]',
#  '[и, глянуть, что, да, как]',
#  '[на, это, и, рассчитано]',
#  '[пока, нет]',
#  '[я, потом, свою, фотку, поставлю]',
#  '[когда, сделаю, что-то, хорошее]',
#  '[пока, так]',
#  '[и, что, это, было]',
#  '[я, бы, оч, испугалась, наверное]',
#  '[в, смысле, где, конкретно]',
#  '[город, же, сказал]',
#  '[населенный, пункт]',
#  '[а, что, она, еще, хотела]',
#  '[ваня, теперь, будет, с, приятной, компанией, спать]',
#  '[я, гуляю]',
#  '[пока, что, отвечаю, пошли]',
#  '[я, же, предлагала]',
#  '[кинб, пока, афишу, я, позже, отвечу]',
#  '[у, тебя, винда, на, компе]',
#  '[вот, и, я, об, этом]',
#  '[но, хочется, верить, что, не, пиратская]',
#  '[хочу, сбросить]',
#  '[потому, что, не, огу, очистить, вручную]',
#  '[тут, чел, веселый, рассказывает, как, установить, винду]',
#  '[шутки, на, 100, баллов]',
#  '[да, это, понятно]',
#  '[я, уже, час, видео, смотрю]',
#  '[запиши, видео, где, вы, просто, смотрите, в, камеру, и, ничего, не, говорите]',
#  '[10, сек, минимум]',
#  '[я, блондинка, теперь]',
#  '[ты, же, знаешь, да]',
#  '[ну, относительно, блондинка]',
#  '[там, переход, на, волосах]',
#  '[корни, мои]',
#  '[концы, белые]',
#  '[у, вани, была, ща]',
#  '[я, с, компа]',
#  '[я, больше, не, хочу, быть, русой]',
#  '[белку, ищут]',
#  '[а, ты, не, спрятался]',
#  '[это, кто]',
#  '[а, кто, это]',
#  '[музыка, топ]',
#  '[тут, у, одной, девушки, свадьба]',
#  '[мне, захотелось, оч, на, свадьбу]',
#  '[с, тобой, сложно, заскучать]',
#  '[я, просто, счастлива]',
#  '[я, из-за, винды, немного, тревожилась]',
#  '[а, есть, разница, в, браузерах]',
#  '[в, плане, функционала]',
#  '[да, не]',
#  '[его, нахуй]',
#  '[я, между, яндексом, и, хромом, выбираю]',
#  '[не, хочу]',
#  '[мне, нравятся, сервисы, яндекс]',
#  '[карты, почта]',
#  '[я, часто, ими, пользуюсь]',
#  '[типо, шума, много]',
#  '[в, разнос, пошел]',
#  '[такой, марк, мне, нравится, очень]',
#  ...]

# %%
# assemble lines: concatenate title and description
from nltk import WordPunctTokenizer
tokenizer = WordPunctTokenizer()
lines = [
    ' '.join(
        tokenizer.tokenize(line.lower())
    ) for line in tqdm(data)
]
# Out:
#   0%|          | 0/3542 [00:00<?, ?it/s]

# %%
lines
# Out:
# ['[ марк , так , что , вы , там , с , артёмом , делали ]',
#  '[ вся , инфа , упомянутая , в , нашей , беседе , конфиденциальна ]',
#  '[ там , же , с , первого , раза , не , у , всех , эффект , бывает ]',
#  '[ это , правда ]',
#  '[ купи , второй , раз ]',
#  '[ и , проверь ]',
#  '[ нашел , приключения ]',
#  '[ он , блин , выпил ]',
#  '[ просто , слов , нет ]',
#  '[ ну , че ]',
#  '[ понравился , гаш ]',
#  '[ ну , может , второй , раз , реально , будет , лучше ]',
#  '[ а , артёму , как ]',
#  '[ он , же , уже , пробовал ]',
#  '[ мб , не , мерещится ]',
#  '[ я , уже , об , этом , слышала ]',
#  '[ кто - то , и , в , прямь , так , сделал ]',
#  '[ думаю , что , нет ]',
#  '[ я , боюсь , подобных , технологий ]',
#  '[ мне , кажется ]',
#  '[ если , бы , я , была , пещерным , человеком ]',
#  '[ я , бы , осталась , сидеть , в , пещере ]',
#  '[ я , вроде , объяснила , свою , позицию ]',
#  '[ пока , это , не , будет , у , большинства , людей ]',
#  '[ пока , не , увижу ]',
#  '[ что , с , ними , все , ок ]',
#  '[ не , поставлю , себе ]',
#  '[ человеческий , страх ]',
#  '[ а , ты , смотрел , токийский , гуль ]',
#  '[ ну , ок , тогда ]',
#  '[ я , попыталась , посмотреть , твоего , ванпачмана ]',
#  '[ но , что - то , не , пошло ]',
#  '[ я , не , знаю , стоит , ли ]',
#  '[ я , думала , может , ты , смотрел ]',
#  '[ и , хотела , спросить , совет ]',
#  '[ 999 , %]',
#  '[ но , оно , вроде , многим , зашло ]',
#  '[ это , анимэ ]',
#  '[ ну , я , знаю , сюжет ]',
#  '[ и , первую , серию , когда - то , смотрела ]',
#  '[ сообщения , выше , не , прочла ]',
#  '[ трейлер , выглядит , как , законченный , фильм ]',
#  '[ постер , выглядит , очень , круто ]',
#  '[ а , там , что , ли , инструкции , не , было ]',
#  '[ уже , неактуально ]',
#  '[ но , ее , я , раньше , прочитала ]',
#  '[ он , заболел , короной ]',
#  '[ мне , кажется , многие , болели ]',
#  '[ хорошо , что , у , него , это , незаметно , прошло ]',
#  '[ ты , можешь , спросить , у , артема ]',
#  '[ код , от , конфы ]',
#  '[ по , инфе ]',
#  '[ все , равно , спасибо ]',
#  '[ не , помню ]',
#  '[ ща , гляну ]',
#  '[ в , 3 ]',
#  '[ было , что - то , задано ]',
#  '[ лю , пиздец ]',
#  '[ электромагнитные , бури ]',
#  '[ а , чей , крым ]',
#  '[ на , вопрос , вопросом , не , отвечают ]',
#  '[ ты , спросил ]',
#  '[ как , я , считаю ]',
#  '[ после , заданного , мной , вопроса ]',
#  '[ но , тем , не , менее ]',
#  '[ чей , вопрос , выше ]',
#  '[ но , факт ]',
#  '[ есть , факт ]',
#  '[ какую , вторую , часть ]',
#  '[ по , математике ]',
#  '[ или , нет ]',
#  '[ на , сегодня ]',
#  '[ сейчас , кину ]',
#  '[ геометрию , не , делала ]',
#  '[ если , будут ]',
#  '[ ты , идешь , на , френ ]',
#  '[ есть , номер , сони ]',
#  '[ первое , июня ]',
#  '[ праздник , ребенка ]',
#  '[ весьма , кстати , будет , пьянка ]',
#  '[ последнее , предложение , в , кавычках ]',
#  '[ это , возможно ]',
#  '[ это , самое , глупое ]',
#  '[ не , учиться , на , своих , ошибках ]',
#  '[ есть , какие - то , новости ]',
#  '[ по , поводу , пароля ]',
#  '[ от , френа ]',
#  '[ возможно , нет ]',
#  '[ это , что , за , игна ]',
#  '[ вот , когда , ты , в , следующих , раз , спросишь , могу , ли , я , кинуть , тебе , дз ]',
#  '[ я , тебе , просто , отвечу , да ]',
#  '[ и , все ]',
#  '[ ну , теперь , понятно ]',
#  '[ это , фильм ]',
#  '[ умная , дама ]',
#  '[ кажется , у , меня , вот - вот , начнётся , никотиновое , голодание ]',
#  '[ тк , жижа , заканчивается ]',
#  '[ надеюсь , что , я , буду , нормальной , в , этот , период ]',
#  '[ это , обязанность , папы ]',
#  '[ она , мне , это , уже , сегодня , сказала ]',
#  '[ это , птица ]',
#  '[ а , не , штука ]',
#  '[ ищешь , себе , собеседника , который , выслушает , всю , твою , бредятину , в , дни , запоев ]',
#  '[ что , даже , он , это , не , выдержит ]',
#  '[ ну , мучай , животных ]',
#  '[ иначе , натравлб , на , тебя ]',
#  '[ лблей , борющихся , за , защиту , животных ]',
#  '[ я , думала , змеи , тебе , больше , по - душе ]',
#  '[ тут , ты ]',
#  '[ должен , сказать ]',
#  '[ что , тебе , и , меня , хватает ]',
#  '[ я , бы , не , рискнула , так , назватт ]',
#  '[ ну , значит , и , тебя ]',
#  '[ ведь , я ]',
#  '[ умнее , тебя ]',
#  '[ но , не , факт , что , проживёт ]',
#  '[ а , кому , она , должна ]',
#  '[ голос , хороший ]',
#  '[ но , это , решаемые , вопрос ]',
#  '[ на , это , я , не , обратила , внимания ]',
#  '[ что - то , было , задано , по , математике ]',
#  '[ как , ты , об , этом , узнал ]',
#  '[ что , это , ща , параша ]',
#  '[ сразу , видно ]',
#  '[ бот , какой - то ]',
#  '[ типо , у , тебя , своих , фоток , нет ]',
#  '[ поэтому , пришлось , взять , фото , своих , врагов ]',
#  '[ у , меня , естт ]',
#  '[ сейчас , пришлю ]',
#  '[ ты , на , фотках , полнейший , угар ]',
#  '[ и , редкий , феномен ]',
#  '[ тк , тебя , сфоткать , нереально ]',
#  '[ а , почему , все , в , аниме , стиле ]',
#  '[ поч , поч ]',
#  '[ с , опытом , видимо ]',
#  '[ я , думала , надо , ли , оно , мне ]',
#  '[ можно , так , выкладывать ]',
#  '[ выглядит , прикольно ]',
#  '[ и , тебя ]',
#  '[ серьезно , знал ]',
#  '[ я , вообще , бы , не , подумаоа ]',
#  '[ но , только , если , бы , это , не , сережа , писал ]',
#  '[ вот , это , да ]',
#  '[ вот , это , вау ]',
#  '[ очень , нравиться , мне , такоеодобряю ]',
#  '[ как , красиво ]',
#  '[ так , это , что ]',
#  '[ 5 , o , ’, clock ]',
#  '[ да , неважно , какие ]',
#  '[ а , у , тебя , скока ]',
#  '[ ты , еще , падал , этой , зимой ]',
#  '[ в , плане ]',
#  '[ что , значит , конечно ]',
#  '[ в , твоем , случае , это , не , применимо ]',
#  '[ но , мне , кажется ]',
#  '[ что , из - за , того , что , я , один , раз , не , позволила , себе , упасть , нога , потерпела , поражение ]',
#  '[ болит , немного ]',
#  '[ ну , типо ]',
#  '[ чтобы , удержаться , нужно , много , сил ]',
#  '[ мб , перенапрягла , ее ]',
#  '[ а , может , об , стул , стукнулась ]',
#  '[ а , я , начала , носить , ботинки , но , осенние ]',
#  '[ а , челси , тебе , не , нрав ]',
#  '[ это , модели ]',
#  '[ не , бренд ]',
#  '[ хотя , зима , уже , подходит , к , концу ]',
#  '[ ты , любишь , техно ]',
#  '[ и , кстати ]',
#  '[ ваня , сказал , что , ты , ищешь , смысл , в , тату ]',
#  '[ зач , и , поч ]',
#  '[ можно , же , просто , красиво ]',
#  '[ мысли , гениев , сходятся ]',
#  '[ а , тебе , он , нужен ]',
#  '[ ты , цже , решился ]',
#  '[ ты , искал , еще , каких - то , челиков ]',
#  '[ я , нашла , студию , мини , тату , только , в , которой , у , меня , подруга , била ]',
#  '[ там , дешевле , но , хз , мини , ди , у , меня ]',
#  '[ по , факту , у , меня , 6к , на , тату , есть , сейчас ]',
#  '[ тебе , цена , такая ]',
#  '[ мне , она , написала , что , моя , татушка , будет , в , районе , 7 , зависит , от , конечного , эскиза , я , написала , размер , 3х4 ]',
#  '[ а , твои , родители , в , курсе ]',
#  '[ даже , слишком ]',
#  '[ ого , вот , это , жаба ]',
#  '[ вот , это , класс ]',
#  '[ не , так , сильно , как , лягушки , и , жабы …]',
#  '[ взгляните , на , это …, 👀\\\\ n , link , https // pinit / 2iqsz0y ]',
#  '[ это , доброе , утро , или , спокойной , ночи ]',
#  '[ я , еще , и , заболела ]',
#  '[ мне , нравятся , эти , чуваки , все , больше , и , больше ]',
#  '[ похоже , на , то ]',
#  '[ тебе , удачи , на , экзе ]',
#  '[ да , у , меня , была , темпа , 15 , дня , сейчас , горло , тревожит , а , в , остальном , бодрячком ]',
#  '[ дааа , сейчас , с , этим , жопа ]',
#  '[ может , он , непонятый , гений ]',
#  '[ а , ты , не , знаешь , почему , в , моей , игрушке , слово , читер , запрещенное , слово ]',
#  '[ не , я , раньше , много , играла ]',
#  '[ типа , фортнайта ]',
#  '[ и , там , в , чате , запрещено , слово , читер , по - моему ]',
#  '[ его , нельзя , написатт ]',
#  '[ о , мой , бог ]',
#  '[ аа , меня , обижают , спидаки , что , делать ]',
#  '[ нечестно , получается ]',
#  '[ это , где , такое ]',
#  '[ и , как , обидеть ]',
#  '[ больше , ни , во , что ]',
#  '[ я , месяца , два , назад , неожиданно , правилась , с , зависимостью , к , играм ]',
#  '[ желание , просто , пропала ]',
#  '[ несколько , лет , не , пропадало ]',
#  '[ и , тут , вот , тебе , на ]',
#  '[ само , собой ]',
#  '[ только , англ ]',
#  '[ еще , есть , фр , и , нем ]',
#  '[ но , я , выбрала , англ ]',
#  '[ с ++, джава , в , следющем , семестре , питон ]',
#  '[ самые , основные ]',
#  '[ полина , узнала , через , знакомых , какие , языки , сейчас , нужны ]',
#  '[ вот , эти , три , и , назвала ]',
#  '[ только , нас , так , учат …]',
#  '[ работы , дают , и , проверяют , остальное , сам ]',
#  '[ типо , сложно , по , сути , самообучение , но , под , присмотром ]',
#  '[ но , в , этом , году , по , джаве , препод , был , хороший , жаль , что , я , не , ходила ]',
#  '[ да , мне , кажется , что , языки , не , особая , проблема , выучить , можно , за , пару , месяцев , один , есди , прям , ботать ]',
#  '[ ну , у , меня , сопли , пока , тусуюсь , дома , экз , скоро ]',
#  '[ пока , результатов , нет ]',
#  '[ ты , напиши , в , беседу , потока , пусть , поднапрягутся ]',
#  '[ тебя , не , только , группа , не , любить , будет ]',
#  '[ но , и , весь , поток ]',
#  '[ представь , какой , масштаб ]',
#  '[ не , хиханьки , да , хаханьки , уже , будет ]',
#  '[ да , я , поняла ]',
#  '[ он , спас , всю , группу , ценой , своей , жизни ]',
#  '[ не , повезло , челу , по , всем , пунктам ]',
#  '[ люди , извращенцы ]',
#  '[ да , я , иногда , расстраиваюсь , из - за , перевода ]',
#  '[ а , в , чем , прикол ]',
#  '[ связано , с , никой ]',
#  '[ так , стало , понятно ]',
#  '[ я , не , видела , приношу , свои , свои , извинения , за , игнор ]',
#  '[ напомни , тебе , рассказать , про , трипофобию ]',
#  '[ кое - что , поинтереснее ]',
#  '[ я , ночью , проверю ]',
#  '[ вообще , должен , был ]',
#  '[ сделаем , ставки ]',
#  '[ кому , дарит , сережа ]',
#  '[ так , нечестно ]',
#  '[ значит , для , тебя , не , сектор , приз ]',
#  '[ мне , скажешь ]',
#  '[ ну , марк ]',
#  '[ у , меня , твой , джул ]',
#  '[ господи , безумие , какое - то ]',
#  '[ даже , не , знаю , как , это , выглядит ]',
#  '[ или , у , тебя , в , процессе , чего - то , сломался ]',
#  '[ не , стану ]',
#  '[ ничего , не , поняла ]',
#  '[ метери , кожухе ]',
#  '[ вот , чего , ты , все , время , туда , лезешь ]',
#  '[ уже , ведь , была , история ]',
#  '[ ты , сказал , что , побьешь , себя ]',
#  '[ если , еще , раз , чего - то , там ]',
#  '[ можешь , бить ]',
#  '[ боже , мой ]',
#  '[ и , как , до , тебя , дошло ]',
#  '[ типо , радиус , уменьшился ]',
#  '[ у , блютуза ]',
#  '[ сам , бог , смеется ]',
#  '[ над , марком , хаустовым ]',
#  '[ ничему , тебя , жизнь , не , учит ]',
#  '[ а , дорого , новый , стоит ]',
#  '[ чтобы , заменить ]',
#  '[ или , тебе , нет , особый , нужды ]',
#  '[ напиши , мне , завтра , в , часика , 4 , про , джул , на , всякий , случай ]',
#  '[ ты , же , пьяный ]',
#  '[ ты , че , творишь , вообще ]',
#  '[ иди , спать ]',
#  '[ сейчас , же ]',
#  '[ лучше , завтра ]',
#  '[ утро , вечера , мудренее ]',
#  '[ просто , ты , сейчас , можешь , быть , менее , осторжным , и , ловким ]',
#  '[ лучше , реально , поспать ]',
#  '[ сладких , снов , марк ]',
#  '[ нечего , было , вносить , корректировки , в , комп ]',
#  '[ этот , чел , ебанутый ]',
#  '[ я , с , ним , на , съемках , была , как - то ]',
#  '[ с , малолетними , девочками , флиртовал ]',
#  '[ кто - то , говорил , что , у , него , кучу , скандалов , по , поводу , сексуальных , наклонностей ]',
#  '[ а , почему , ты , один , говоришь , что , пойдешь , тогда ]',
#  '[ все - таки , нет ]',
#  '[ я , устала ]',
#  '[ как , штирлец , связан , с , тук , тук ]',
#  '[ я , поняла ]',
#  '[ как , с , этим , штрилец , связан ]',
#  '[ в , дверь ]',
#  '[ по , голове ]',
#  '[ блин , надо , глянуть , фильм ]',
#  '[ по , пн , в , powerhouse , jazz , jam , с , 8 , часов , вечера ]',
#  '[ хочешь , пойти , виз , ми ]',
#  '[ этот , jazz , jam , только , по , пн ]',
#  '[ вход , свободный ]',
#  '[ искала , другие , места ]',
#  '[ но , во , многих , по , билетам ]',
#  '[ я , хотела , в , этот , пн , пойти ]',
#  '[ марк , а , точно , идем ]',
#  '[ можно , и , без , брлни , прийти ]',
#  '[ если , ты , можешь , то , было , здорово ]',
#  '[ у , меня , бабушка , приехала ]',
#  '[ я , тут , бегаю , и , пляшу ]',
#  '[ так , идем ]',
#  '[ просто , нас , только , двое ]',
#  '[ и , не , факт , что , там , много , людей , будет ]',
#  '[ да , и , прикольная , штука ]',
#  '[ хочу , сходить ]',
#  '[ это , на , таганке ]',
#  '[ сам , джаз , джем , начнётся , в , 8 ]',
#  '[ но , мы , можем , как , раньше , так , и , позже ]',
#  '[ паспорт , не , забудь ]',
#  '[ давай , встретимся , в , 730 , на , таганке ]',
#  '[ и , если , можешь , возьми , повербенк , пжл ]',
#  '[ уже , там ]',
#  '[ если , хочешь ]',
#  '[ как , тебе , удобно ]',
#  '[ я , сейчас , в , автобусе ]',
#  '[ который , идет , до , киевской ]',
#  '[ так , что , не , могу , точно , сказать ]',
#  '[ полагаю , что , к , назначенному , времени ]',
#  '[ там , по - моему , несколько , залов , так , что , надо , еще , понять , куда , сесть ]',
#  '[ или , откроется , зал , с , джазом ]',
#  '[ что , откроется ]',
#  '[ это , не , стеб , я , реально , не , понимаю ]',
#  '[ там , симпатично ]',
#  '[ я , выхожу , из , автобуса ]',
#  '[ и , залетаю , в , метро ]',
#  '[ там , пишут , 12 , мин , ехать ]',
#  '[ 11 , минут ]',
#  '[ а , как , ты , шел ]',
#  '[ типо , не , ощутил , время ]',
#  '[ уууу , понимаю ]',
#  '[ хотя , нет ]',
#  '[ я , велосипедов , не , замечаю ]',
#  '[ опасно , доя , жизни ]',
#  '[ я , потеряла , б ]',
#  '[ я , внутри ]',
#  '[ куда , дальше ]',
#  '[ а , дальше ]',
#  '[ взгляните , на , это …, 👀\\\\ n , link , https // pinit / 1lwjzid ]',
#  '[ у , меня , вопрос , вк , тебя , напрягает , из - за , того , что , он , несекретный , или , в , чем , прикол ]',
#  '[ всё - таки , хотят , уже ]',
#  '[ но , мне , от , этого , как - то , никак ]',
#  '[ а , до , этого , не , могла ]',
#  '[ вот , это , точно , могла ]',
#  '[ ну , работать , да ]',
#  '[ я , думала ]',
#  '[ что , они , к , чему - то , более , конкретному , придут ]',
#  '[ да , просто , уже , были , такие , переговоры ]',
#  '[ ни , к , чему , они , не , привели ]',
#  '[ оу , фак ]',
#  '[ я , теперь , тоже , себе , такой , хочу ]',
#  '[ ты , пробовал , рисовать ]',
#  '[ да , норм , все ]',
#  '[ как , есть ]',
#  '[ хочу , тоже , такое ]',
#  '[ нет , у , нас , такого , не , было ]',
#  '[ первый , о , ком , я , подумала , был , каркарыч , но , после , ее , аргументов , передумала ]',
#  '[ реальность , все , с , какими - то , тараканами ]',
#  '[ а , ты ]',
#  '[ она , паникер ]',
#  '[ и , мамочка ]',
#  '[ если , соглашаться , на , тараканов ]',
#  '[ то , он ]',
#  '[ самый , разумный , хомосапиенс ]',
#  '[ хитрость , порождена , высоким , интеллектом , и , способностью , анализировать ]',
#  '[ ну , а , совунья , в , облаках , жила ]',
#  '[ хочу , глянуть , серию , с , двойником , лосяша ]',
#  '[ нет , ее , туда , запульнули , и , она , не , моогла , спуститься ]',
#  '[ серия , невоспитанный , клон ]',
#  '[ случайно , нет ]',
#  '[ ну , у , сестры , есть , понятное , дело ]',
#  '[ а , все , что , ли ]',
#  '[ нельзя , будет ]',
#  '[ он , же , просто , офис , закрыл ]',
#  '[ а , работать , будет ]',
#  '[ в , чем , прикол ]',
#  '[ у , меня , тоже , спотифай ]',
#  '[ подожди , я , пытаюст , найти , инфу , по , поводу , этого ]',
#  '[ я , тоже , тут , читала ]',
#  '[ а , если , сестру , просить , то , как , оно , будет , сниматься , тут , рубли , а , у , нее , другие , валюты , дороже , будет , в , разы , да ]',
#  '[ если , я , слечу , с , подписки , то , у , меня , уже , не , будет , избранной , музыки , и , исчезнет , моя , сохраненная , музыка , реклама , будет ]',
#  '[ по - моему , исчезнет , даже , то , что , ты , сейчас , лайкнул , когда , подписка , вернется , то , и , вернется , то , что , ты , лайкнул ]',
#  '[ короче , похуй , я , буду , в , телеге , музыку , слушать ]',
#  '[ у , меня , летом , не , было , подписки , еще , на , спотифай ]',
#  '[ и , моя , сестра , подсказала , что , в , телеге , есть , боты , которые , ищут , нужные , треки , и , скачивают , их ]',
#  '[ соответственно , их , можно , слушать , без , интернета ]',
#  '[ я , не , знаю , что , для , тебя , важнее , всего ]',
#  '[ мне , главное , отсутсвие , рекламы ]',
#  '[ и , без , интернета , иногда , нужно ]',
#  '[ в , метро , не , всегда , ловит ]',
#  '[ бляяяяяяя , нееет ]',
#  '[ это , типо , дорого ]',
#  '[ литр , бензина , в , италии , стоит , 224 , евро ]',
#  '[ короче , ботов , можно , поискать , в , телеге , они , есть , рабочие , но , их , частенько , блокируют …]',
#  '[ ты , не , рад ]',
#  '[ должна , же , быть , причина ]',
#  '[ это , какое - то , научный , термин , или , ты , придумал , и , what , do , you , mean ]',
#  '[ красивая , собака ]',
#  '[ другая , на , улице ]',
#  '[ потом , узнаю , что , это ]',
#  '[ не , торопи , событи ]',
#  '[ у , меня , спотифай , вылетел ]',
#  '[ у , тебя ]',
#  '[ пошли , нахуй , все ]',
#  '[ дискорд , тоже …]',
#  '[ или , с , россией ]',
#  '[ смотря , какой ]',
#  '[ может , для , меня , это , не , важно ]',
#  '[ это , намек ]',
#  '[ хочешь , укр , паспорт ]',
#  '[ папа , сказал , я , бы , на , твоем , месте , задумался ]',
#  '[ мне , какая , польза , статус , мой , муж , марк , хаустов ]',
#  '[ зная , тебя , ты , будешь , скрывать , часть , дохода ]',
#  '[ я , не , замечала , обмана , в , мой , адрес ]',
#  '[ надеюсь , ты , не , погубишь , мое , доверие ]',
#  '[ иначе , вот , так , будет , с , тобой ]',
#  '[ короче , если , что ]',
#  '[ ты , первый , в , очереди ]',
#  '[ я , знаю , что , украинцы , понимают , белорусский , и , наоборот ]',
#  '[ на , русский , тоже , похоже , очень ]',
#  '[ вот , вот ]',
#  '[ местами , просто , слова , кардинально , отличаются ]',
#  '[ ты , как , всегда ]',
#  '[ просто , пришла , пожелать , тебе , спокойной , ночи ]',
#  '[ я , недавно , думала , почему , коммунизм , это , плохо ]',
#  '[ надо , почекать , инфу ]',
#  '[ немного , ленина , в , голову , стукнуло ]',
#  '[ не , не , я , посмотрю , видео ]',
#  '[ потому , что , мне , непонятно ]',
#  '[ да , не ]',
#  '[ типо , сссрver2 ]',
#  '[ я , в , такое , не , поверю ]',
#  '[ ожидаемо , в , принципе ]',
#  '[ впн , нужен ]',
#  '[ у , тебя , конечно , не , айос ]',
#  '[ но , мб , посоветуешь , что - то ]',
#  '[ а , можно , на , двух , устройствах ]',
#  '[ это , для , компа , или , тел ]',
#  '[ сейчас , попробую ]',
#  '[ сколько , ты , платишь 🤔]',
#  '[ или , это , окей , для , впн ]',
#  '[ мое , уважение ]',
#  '[ мне , сейсас , стало , страшно , что , там , без , входа , и , уч , запись , берется , автоматически , запись , эпл ]',
#  '[ кто , не , рискует , тот , не , пьет ]',
#  '[ а , ты , будешь , в , инсте , сидеть ]',
#  '[ или , тебе , пофиг ]',
#  '[ а , потом , в , даркнет , залететь ]',
#  '[ интересно , происходящее , же , повлияло , на , дилеров ]',
#  '[ о , как ]',
#  '[ так , а , еще , вопрос ]',
#  '[ у , меня , завтра , подписка , выходит , на , спотифай ]',
#  '[ сестра , сама , предложила , продлить ]',
#  '[ короче , как , думаешь , сколько , накинется , на , оплату ]',
#  '[ с , укр , карточки ]',
#  '[ в , рубли ]',
#  '[ так , дороже , вроде ¿]',
#  '[ ты , для , себя , хочешь ]',
#  '[ да , только , деньги , не , мне , нужны , а , им ]',
#  '[ ща , я , буду , думать ]',
#  '[ так , продолжай ]',
#  '[ я , просто , в , этом , ноль ]',
#  '[ вроде , получилось ]',
#  '[ завтра , еще , проверим ]',
#  '[ карту , нельзя , изменить , в , спотифай ]',
#  '[ а , саундклауд , работает ]',
#  '[ туда , можно , перекинуть , автоматом , все , плейлисты , и , избранные ]',
#  '[ сейчас , пробую ]',
#  '[ никогда , не , пользовалась , саунд , клаудом ]',
#  '[ там , окей ]',
#  '[ не , я , прям , сейчас , пробую , это , сделать ]',
#  '[ какой - то , сайт ]',
#  '[ надеюсь , данные , не , спиздят ]',
#  '[ что , это , значит ]',
#  '[ не , похоже , на , санитаров ]',
#  '[ а , что , он , делал ]',
#  '[ а , что , это , значит ]',
#  '[ для , меня , это , ни , о , чем , не , говорит ]',
#  '[ просто , для , меня , эти , личности , конкретно , непонятны , к , сожалению ]',
#  '[ ничего , о , них , не , знаю ]',
#  '[ как , тебе ]',
#  '[ bold , сила , в , правде , за , победу \\\\ n , в , продаже , с , 22 , марта ]',
#  '[ подпишись , на , канал , и , поставь , лайк ]',
#  '[ такие , приколы , мне , нравятся ]',
#  '[ в , смысле ]',
#  '[ почему , забрали ]',
#  '[ сегодня , я , задалась , вопросом , почему , ты , мне , не , пишешь ]',
#  '[ а , вот , в , вк , есть , защита , от , чсв ]',
#  '[ а , мама , что ]',
#  '[ какого , хрена , забрали ]',
#  '[ а , тебе , ок , без , них ]',
#  '[ видимо , творческий , кризис ]',
#  '[ ты , не , согласился ]',
#  '[ я , поэтому , и , не , подписалась ]',
#  '[ не , ну , а , что ]',
#  '[ ты , звонил ]',
#  '[ а , тебе , дадут , рабочую , визу ]',
#  '[ или , в , рашке ]',
#  '[ я , даже , не , знаю , что , это ]',
#  '[ а , конкретнее , можно ]',
#  '[ вообще , именно , такого , названия , дисциплины , не , было ]',
#  '[ но , мб , что - то , похожее , было ]',
#  '[ сейчас , бегу , в , туалет ]',
#  '[ ты , тоже ]',
#  '[ это , на , выпускной ]',
#  '[ есть , два , вопроса ]',
#  '[ а , модет , и , больше ]',
#  '[ ты , общаешься , с , ваней ]',
#  '[ ты , бы , хотел , погулять , втроем ]',
#  '[ такое , трио , кайфовое , прям , было , ьы ]',
#  '[ благодаря , вам ]',
#  '[ там , еще , вопрос , будет ]',
#  '[ жду , ответик ]',
#  '[ ты , че , выходишь ]',
#  '[ это , алена ]',
#  '[ третий , вопрос ]',
#  '[ а , ваня , захотел , бы ]',
#  '[ или , лучше , у , него , спрашиватт ]',
#  '[ я , не , знаю , куда ]',
#  '[ но , идея , с , баром , не , супер , привлекательна ]',
#  '[ ну , это , второй , вопрос ]',
#  '[ пойдем , ли , мы , куда - то ]',
#  '[ а , я , в , геншин , начала , играть ]',
#  '[ этот , с , тотушкой ]',
#  '[ ты , спросил ]',
#  '[ то , есть , ответ , нет ]',
#  '[ марк , помнишь , ты , мне , недавно , звонил , ты , реально , случайно , позвонил ]',
#  '[ или , что - то , произошло ]',
#  '[ да , просто , потом , мысли , дурные , настигли ]',
#  '[ у , меня , пять , выпало ]',
#  '[ а , у , тебя , скока , будет ]',
#  '[ 1 , у , тебя ]',
#  '[ так , можно , споры , в , телеге , решать ]',
#  '[ я , вообще - то ]',
#  '[ у , меня , больше ]',
#  '[ у , меня , только , 4 …]',
#  '[ на , удивление , эта , пара , получилась , тютелька , в , тютельку ]',
#  '[ мне , дали , 4 , очка ]',
#  '[ у , даши , 51 …]',
#  '[ она , сотку , хочет ]',
#  '[ со , второго , раза , блять ]',
#  '[ я , видела ]',
#  '[ где , слушать , музыку ]',
#  '[ там , миксы ]',
#  '[ в , основном ]',
#  '[ вк , походу , остаётся ]',
#  '[ что , фу ]',
#  '[ на , войне , все , средства , хороши ]',
#  '[ bold , top , players , \\\\ n1 , марк , bold , 805 , \\\\ n2 , liza , bold , 703 ]',
#  '[ у , меня , пара , с , душной , преподшей ]',
#  '[ она , нацистка ]',
#  '[ и , не , только ]',
#  '[ она , очень , стара , в , своих , мыслях ]',
#  '[ савок , чисто ]',
#  '[ bold , top , players , \\\\ n1 , марк , bold , 1564 , \\\\ n2 , liza , bold , 645 ]',
#  '[ а , против , войны , слышал ]',
#  '[ просто , могут , не , говорить ]',
#  '[ погнали , в , субботу , в , эту ]',
#  '[ втроем , если , получится ]',
#  '[ когда , сможешь , дать , ответ ]',
#  '[ ну , вообще , это , время , подходит ]',
#  '[ а , ты , как ]',
#  '[ после , пар , ок , будет ]',
#  '[ я , даже , не , знаю ]',
#  '[ погода , позволяет , погулять ]',
#  '[ идем , гулять ]',
#  '[ на , удицу ]',
#  '[ давай , станцию , выберем ]',
#  '[ и , там , встретимся ]',
#  '[ во , сколько , получается ]',
#  '[ оки , доки ]',
#  '[ ване , напишешь , да ]',
#  '[ ты , лучший ]',
#  '[ и , что , это ]',
#  '[ тебе , повезло ]',
#  '[ я , не , сплб ]',
#  '[ это , все ]',
#  '[ доброй , ночи ]',
#  '[ по , факту ]',
#  '[ у , нас , в , экзаменах , такие , вопросы , есть ]',
#  '[ и , их , через , прогу , проверяют ]',
#  '[ а , не , хуйней , страдают ]',
#  '[ еще , и , цвета , можно , выбрать ]',
#  '[ ты , стал , мухомором ]',
#  '[ я , прочитала , зависть …]',
#  '[ по , фрейду ]',
#  '[ откуда , у , тебя ]',
#  '[ типо , булгаков ]',
#  '[ алвингов , такого , не , знаю ]',
#  '[ выглядит , круто ]',
#  '[ ты , можешь , помочь , найти , мне , трек ]',
#  '[ у , меня , не , получается ]',
#  '[ link , https // soundcloudappgoogl / usgrflzctriw29yf9 ]',
#  '[ объясни , пжл , как ]',
#  '[ они , потеряли ]',
#  '[ что , это , вообще , такое ]',
#  '[ как , ты , умудрился , этим , повредить , руку ]',
#  '[ а , еще ]',
#  '[ мне , тоже , очень , нравится , твет , давай , если , будет , концерт , пойдем , туда ]',
#  '[ он , сейчас , их , отменил , но , вдруг ]',
#  '[ потому , что , я , не , понимаю , то , что , ты , кидаешь ]',
#  '[ но , вот , это , к , примеру ]',
#  '[ набор , слов ]',
#  '[ ну , ладно , не , набор , слов ]',
#  '[ но , про , какую , русскую , идею , идет , речь ]',
#  '[ мб , у , него , с , математикой , туго ]',
#  '[ я , не , пониматт ]',
#  '[ дерьмое , приложение ]',
#  '[ иди , в , чемприкол ]',
#  '[ неее , у , меня , не , было , такого ]',
#  '[ я , в , детстве , музыку , не , слушала ]',
#  '[ ну , точнее , музыка , сестры , играла , мне , этого , было , достаточно ]',
#  '[ все , уже ]',
#  '[ у , меня , было , красивл ]',
#  '[ а , ты , что , наделал ]',
#  '[ так , почему , обратно , не , поменят ]',
#  '[ неее , если , бы , было , так , я , бы , тебя , заблокала ]',
#  '[ не , знаю , не , знаю ]',
#  '[ если , вы , все , еще , не , разобрались , как , продлить , подписку , на , spotify , то , вам , помогут , вот , text_link , эти , ребята , href , https // podpiskaorg / spotify / utm_source = telegram , &, utm_medium = cpm , &, utm_campaign = myidem , &, utm_term = april , они , подключат , ваш , аккаунт , к , семейной , премиум - подписке , так , что , вся , медиатека , останется , на , месте , инструкцию , ищите , по , ссылке , выше \\\\ n \\\\ nвсе , работает , четко , подписки , есть , на , 6 , и , 12 , месяцев , а , еще , они , же , могут , вам , помочь , и , с , text_link , подпиской , на , netflix , href , https // podpiskaorg / netflix / utm_source = telegram , &, utm_medium = cpm , &, utm_campaign = myidem , &, utm_term = april ]',
#  '[ ты , как , всегда ]',
#  '[ а , я , не , поняла ]',
#  '[ спотифай , работает ]',
#  '[ без , впн ]',
#  '[ а , что , за , ограничения , цб ]',
#  '[ такое , мне , оч , нравится ]',
#  '[ сколько , тебя , стригли , блять ]',
#  '[ ты , уверен ]',
#  '[ а , фотка , есть ]',
#  '[ а , че , не , так ]',
#  '[ ты , часто , придираешься ]',
#  '[ что , в , этот , раз , тоже ]',
#  '[ в , любом , случае , отрастет ]',
#  '[ не , представляю , тебя , с , таким ]',
#  '[ сейчас , тебе , красиво ]',
#  '[ с , такой , прической ]',
#  '[ оу , фак ]',
#  '[ до , осени , еще , дожить , надр ]',
#  '[ еще , бы , знать , что , это ]',
#  '[ ща , гляну ]',
#  '[ мне , не , зашло ]',
#  '[ я , такого , не , знаю ]',
#  '[ до , 28 , мая , время , есть ]',
#  '[ гляну , его ]',
#  '[ ты , ее , выгуливаешь ¿]',
#  '[ но , зачем ]',
#  '[ и , ты , падаешь ]',
#  '[ а , как , зовут ]',
#  '[ я , буду , звать , тебя , человеком ]',
#  '[ у , тебя , расистские , наклонности ]',
#  '[ марк , ты , от , какой , станции , будешь , шагать ]',
#  '[ все , я , тебе , больше , не , нужна ]',
#  '[ не , особо , ошибся ]',
#  '[ это , эпл ]',
#  '[ у , меня , такое , чувство , что , вы , мне , с , дашей , не , дорассказали , ваши , падения , за , зиму ]',
#  '[ ты , в , джинсовке , что , ли , ходишь ]',
#  '[ я , же , спрашивала , и , гвоорила , что , веду , счетчик , падений ]',
#  '[ падал , вообще - то ]',
#  '[ все , задокументировано ]',
#  '[ не , помню ]',
#  '[ надеюсь , не , только , физические ]',
#  '[ какой , ты ]',
#  '[ это , как ]',
#  '[ а , что , надо , делать ]',
#  '[ надо , напиться ]',
#  '[ или , что ]',
#  '[ как , так ]',
#  '[ такое , сложно , забыть ]',
#  '[ ах , ты , сука ]',
#  '[ до , сих , пор , не , прочитал ]',
#  '[ ты , меня , заблокал , что , ли ]',
#  '[ раз , не , доставлено ]',
#  '[ ладно , думаю , что , не , заблокал …, надеюсь …]',
#  '[ пройди , тест , на , тип , привязанности ]',
#  '[ хватит , спать ]',
#  '[ link , https // wwwidrlabscom / ru / attachment - style / testphp ]',
#  '[ к , другим , людям ]',
#  '[ я , думаю , что , уловил , в , процессе , суть ]',
#  '[ сидела , я , делала , просроченное , задание , на , гите , не , работала , какая - то , функция , которая , есть , на , линуксе , но , не , на , винде , больше , я , это , не , делала ]',
#  '[ смотрел , очень , странные , дела ]',
#  '[ у , меня , все , ок , было ]',
#  '[ хотела , растянуть , сезон ]',
#  '[ посмотрела , серию , в , один , день ]',
#  '[ остальной , сезон , в , другой ]',
#  '[ мне , не , супер , зашли , спецэффекты , нереалистичные , местами , прям , сильно ]',
#  '[ тут , дофига , русских , хотя , ты , и , сам , я , лумаю , в , курсе ]',
#  '[ но , местами , русские , совершенно , не , русские ]',
#  '[ но , не , специально , как - то , вышло ]',
#  '[ но , не , каждый , второй , марк ]',
#  '[ так , что , не , справедливо ]',
#  '[ у , меня , до , 2 , числа ]',
#  '[ пиздец , правда ]',
#  '[ до , 2 , июля ]',
#  '[ у , тебя ]',
#  '[ ну , так , норм ]',
#  '[ а , когда , доп , день ]',
#  '[ для , сдачи ]',
#  '[ это , да ]',
#  '[ резервный , денб ]',
#  '[ если , что - то , не , сдал , по , разным , причинам ]',
#  '[ есть , один , день , в , конце , сессии , когда , можно , сдать , один , экз ]',
#  '[ и , это , не , будет , пересдачей , считаться ]',
#  '[ будем , по , рации , общаться ]',
#  '[ судя , по , тому , что , ты , мне , это , скинул , ты , дочитал , до , конца , я , в , шоке ]',
#  '[ что , вообще , просиходит ]',
#  '[ это , акне ]',
#  '[ я , сегодня , не , красилась , особо ]',
#  '[ хотелось , побыстрее , сдать ]',
#  '[ тебе , то , зачем ]',
#  '[ у , тебя , все , круто ]',
#  '[ а , ты , умывалками , хорошими , пользуешься ]',
#  '[ это , на , даче , такой , вид ]',
#  '[ ты , айфон , купил ]',
#  '[ я , не , видела ]',
#  '[ у , него , есть , телеграмм ]',
#  '[ какой , мед ]',
#  '[ а , там , будешь , искать , себя , в , разных , сферах ]',
#  '[ хотя , если , пойти , в , какую - то , научную , сферу , тебе ]',
#  '[ вот , это , да , твоей , голове , это , пошло , бы ]',
#  '[ та , да ]',
#  '[ многовато , как - то ]',
#  '[ как , умно , с , твоей , стоооны ]',
#  '[ мейби , бейби ]',
#  '[ не , умирай , пжл ]',
#  '[ я , тебя , задела ]',
#  '[ теперь , уже , и , ты , кислотный ]',
#  '[ давишь , прям ]',
#  '[ почему , в , этот , раз ]',
#  '[ что , происходит ]',
#  '[ ты , ввел , меня , в , ступор ]',
#  '[ я , не , понимаю ]',
#  '[ как , ты , можешь , вычислить , мою , личность ]',
#  '[ по , такому , вопросу ]',
#  '[ тогда , нет ]',
#  '[ я , не , динозавр ]',
#  '[ я , смотрю , в , будущее ]',
#  '[ дикий , прикол , какой - то ]',
#  '[ а , разве , не , могу ]',
#  '[ это , не , мунк ]',
#  '[ но , мейби , бейби ]',
#  '[ реально , оттуда , как , будто , взято ]',
#  '[ я , нарисовала ]',
#  '[ но , это , я , рисовала , на , паре , по , экономике ]',
#  '[ а , там , преподша , такая , блять , нацистка ]',
#  '[ что , да ]',
#  '[ да , и , только ]',
#  '[ подписка , нетфликм ]',
#  '[ или , что ]',
#  '[ с , каким , это ]',
#  '[ у , тебя , задержка , на , два , час ]',
#  '[ да , она , не , глупая , женщина ]',
#  '[ не , думаю , что , в , этом , проблема ]',
#  '[ я , даже , на , гитхабе , ничего , не , постила ]',
#  '[ хотя , должна , была ]',
#  '[ вот , ду , ю , мин ]',
#  '[ я , часов , 6 , назад , пила , водку ]',
#  '[ мне , хуево ]',
#  '[ да , блин ]',
#  '[ еще , и , жара ]',
#  '[ вообще , жопа ]',
#  '[ что , с , аней , вообще , творится ]',
#  '[ я , думаю ]',
#  '[ что , они , подходят , друг , другу ]',
#  '[ вот , и , все ]',
#  '[ еще , синячки , можно , было ]',
#  '[ уважаю , такой , ответ ]',
#  '[ это , кто , там , такой ]',
#  '[ 4 , гб …]',
#  '[ купи , уже , себе ]',
#  '[ а , вышло , хорошо ]',
#  '[ пока , скачивать , не , буду ]',
#  '[ мне , не , нравится , конкретно , образ , алисы ]',
#  '[ ковёр , пиздатый ]',
#  '[ наша , реальность , тебе , не , нравится ]',
#  '[ ну , тут , согласна ]',
#  '[ это , что , такое ]',
#  '[ что , за , программа ]',
#  '[ у , меня , сейчас , нет , на , это , денег ]',
#  '[ да , сделай , уже , себе ]',
#  '[ я , до , сих , пор , оч , хочу ]',
#  '[ но , денег , нема ]',
#  '[ хотя , были ]',
#  '[ окей , тогда , я , вернусь , с , моря , и , займусь , активно , этим , вопросом ]',
#  '[ найди , тогда , студию ]',
#  '[ и , мастера , которые , тебе , заходят ]',
#  '[ а , я , поищу , для , себя ]',
#  '[ та , девушка , улетела , по - моему ]',
#  '[ да , и , хотелось , бы , дешевле , чем , у , нее ]',
#  '[ сначала , надо , стать , популярным ]',
#  '[ давай , я , тебе , сотку , скину ]',
#  '[ кому , рф ]',
#  '[ не , знаю ]',
#  '[ на , 7 , больше ]',
#  '[ всего , лишь ]',
#  '[ лобстеры , конечно ]',
#  '[ сложно , для , понимания ]',
#  '[ это , я , к , счастью , знаю ]',
#  '[ клоун , теперь , премиум ]',
#  '[ он , реально , так , сказал ]',
#  '[ или , это , шутка ]',
#  '[ это , еще , зачем ]',
#  '[ выдавливали , что , ли ]',
#  '[ жж , это , кто ]',
#  '[ 29 , июля , в , доме , культур , пройдет , text_link , образцовая , диско - вечеринка , href , https // wwwinstagramcom / p / cfvstqhlwok , от , команды , a , casa , ребята , превратят , локацию , в , рай , для , сладкоежек , с , сахарной , ватой , и , коктейлями , а , еще , поставят , вагончик , с , мороженым , как , из , детства \\\\ n \\\\ nглавные , гостьи , тусовки , опытная , виниловая , диггерша , karolina , bnv , и , whiez , из , комьюнити , sk8techno , с , грувовой , селекцией , поддержат , артисток , постоянные , резиденты , команды , julia , konor , discopank , и , wezego , с , отборной , подборкой , всех , оттенков , диско - музыки \\\\ n \\\\ nкупить , билеты , можно , text_link , по , ссылке , href , https // acasamusictimepadru / event / 2099695 /, с , промокодом , myidem , вы , получите , скидку , 20 , %]',
#  '[ не , хочу ]',
#  '[ пса , жаль ]',
#  '[ я , вечером , деньги , кину ]',
#  '[ я , опять , с , налом , хожу ]',
#  '[ не , забудь ]',
#  '[ про , промокод ]',
#  '[ напиши , сколько , надо , скинуть , потом ]',
#  '[ какие - то , планы , в , субботу ]',
#  '[ зависит , от , того ]',
#  '[ насколько , классно , будет ]',
#  '[ типо , по , ситуации , смотреть , буду ]',
#  '[ сколько , по , итогу ]',
#  '[ 700 - 20 , %]',
#  '[ а , како , юанк ]',
#  '[ тебе , спасибо ]',
#  '[ да , не , извиняйся ]',
#  '[ это , как , бы , твое , дело ]',
#  '[ ну , ты , туда , на , час , залетишь , или , до , скольки , приблизительно ]',
#  '[ думаю , что , переживу ]',
#  '[ метро , в , час ]',
#  '[ насчет , бара ]',
#  '[ позже , спишемся ]',
#  '[ давай , в , 9 ]',
#  '[ это , на , китай - городе ]',
#  '[ а , в , чем , идти ]',
#  '[ марк , а , у , тебя , есть , какая - нибудь , сумка , через , плечо , аля , спортивная , мне , дать ]',
#  '[ типо , ты , будешь , в , ней ]',
#  '[ а , еще ]',
#  '[ затянулась , ашкой ]',
#  '[ а , она , продолжила , работать ]',
#  '[ из - за , чего , может , быть , не , знаешь ]',
#  '[ вот , я , затягиваюсь , огонек , загорается , и , продолжает , гореть , будто , я , тяну , еще ]',
#  '[ один , раз , было ]',
#  '[ потом , все , ок ]',
#  '[ насчет , сумки ]',
#  '[ я , нашла , у , себя ]',
#  '[ плюс , минус , удобную ]',
#  '[ а , насчет , ашки ]',
#  '[ это , пиздец ]',
#  '[ я , ее , обрезала ]',
#  '[ она , перестала , выключатся ]',
#  '[ надеюст , что , не , взорвется ]',
#  '[ мне , неудобно , говорить ]',
#  '[ ты , уже , там ]',
#  '[ и , что , делать , будем ]',
#  '[ какие , еще , варианты , есть ]',
#  '[ я , знаю , бир , енд , фрайс ]',
#  '[ но , там , тоже , много , будет , скорее , всего ]',
#  '[ прям , совсем , некуда ]',
#  '[ я , от , площади , революции ]',
#  '[ но , я , опаздываю ]',
#  '[ на , славянке , только ]',
#  '[ а , может , лучше ]',
#  '[ еще , в , бары , заглянешь ]',
#  '[ а , название ]',
#  '[ может , лучше , в , пестики ]',
#  '[ хотелось , дожить , до , завтра ]',
#  '[ ну , ок ]',
#  '[ я , шагаю ]',
#  '[ ты , где ]',
#  '[ не , вижу ]',
#  '[ может , я , не , там ]',
#  '[ значит , название , не , то ]',
#  '[ я , в , этот , пришла ]',
#  '[ тут , еще , диджей , сет ]',
#  '[ тут , круто ]',
#  '[ и , мест , дофига ]',
#  '[ where , r , u ]',
#  '[ я , дома , все , хорошо ]',
#  '[ я , вообще , не , в , восторге ]',
#  '[ а , мой , пиджак , тебе , не , подойдет , вхаххахахха ]',
#  '[ вообще , черный , пиджак ]',
#  '[ это , стиль ]',
#  '[ мне , нравится , на , парнях ]',
#  '[ но , он , оверсайзный , так , то ]',
#  '[ на , мне , так , точно ]',
#  '[ что , за , прикол , с , женским , и , мужским , стаканом ]',
#  '[ если , они , планировали , сделать , такое ]',
#  '[ то , как , минимум , мне , непонятно , это , разделение ]',
#  '[ но , учиться , за , границей , можно , много , еще , где , \\\\ n \\\\ nи , учеба , сейчас , это , самый , простой , способ , эмиграции , на , карте , можно , увидеть , где , есть , полное , покрытие , расходов \\\\ n \\\\ nпо , дедлайнам , сейчас , можно , успеть , податься , на , следующие , гранты , которые , полностью , покрывают , daad , германия , erasmus , mundus , европа , hungaricum , stipendium , венгрия , visby , швеция , gks , южная , корея , и , поступить , весной / осенью , 2023 \\\\ n \\\\ n 🇬🇷 еще , сейчас , есть , вариант , поступить , на , языковые , курсы , в , греции , после , которых , можно , учиться , там , бесплатно , на , греческом \\\\ n \\\\ nчтобы , увеличить , шансы , лучше , использовать , проверенные , маршруты , ребята , из , univibes , помогают , с , документами , сопровождают , на , всем , пути , а , так , как , кураторы , уже , выигрывали , эти , гранты , они , знают , как , это , делать \\\\ n \\\\ nеще , у , них , можно , купить , гайд , по , всем , стипендиям , получить , первую , бесплатную , консультацию , оценить , свои , шансы , подобрать , программу , в , общем , если , не , хватает , импульса , то , вот , он , промокод , на , 7 , %, cкидки , -, mishapetrow \\\\ n \\\\ nих , text_link , телеграм , канал , href , https // tme / univibes , c , грантами , подписывайтесь \\\\ n \\\\ nкто , сейчас , куда , поступает , рассказывайте ]',
#  '[ да , понятное , дело ]',
#  '[ я , сейчас , рентген , делала ]',
#  '[ мне , сказали , что , у , меня , чистые , легкие ]',
#  '[ спросили , курю , ли , я ]',
#  '[ может , реально , все , хорошо ]',
#  '[ гражданство , буду , делать ]',
#  '[ вот , это , у , меня , давление , и , скачет , обмороки , и , кровь , носом ]',
#  '[ у , меня , в , октябре , внутренний , паспорт , станет , просроченным ]',
#  '[ я , туда , не , поеду ]',
#  '[ в , украине , жить , не , планирую ]',
#  '[ тем , более , украинский , паспорт , у , меня , никто , не , заберет ]',
#  '[ пока , нет ]',
#  '[ эти , года , не , требовали ]',
#  '[ такой , пушистый ]',
#  '[ я , думала , что , ты , его , загубишь ]',
#  '[ я , думала , что , они , просто , языками , чешут ]',
#  '[ пока , не , факт , что , примут ]',
#  '[ и , там , же , многие , страны , за , мир ]',
#  '[ так , что , не , думаю ]',
#  '[ что , это , случится ]',
#  '[ я , хочу , на , тебя , пожаловаться ]',
#  '[ я , прошлой , ночью , глядела , на , свою , косметику , и , вспомнила , твой , заскок , когда , ты , все , оттираешь , от , грязи , теперь , вся , моя , косметика , чистая ]',
#  '[ и , если , можно , нет , ли , каких - то , проблем , с , этим ]',
#  '[ может , и , есть ]',
#  '[ а , есть , какая - то , разница ]',
#  '[ есть , карта , немецкого , банка , но , она , для , соцвыплат , лучше , с , неё , никаких , операций , не , проводить , я , могу , отдельную , карту , открыть , в , немецком , банке , в , евро , ещё , я , жду , доставку , карты , binance , пластиковую , карту , я , имею , ввиду ]',
#  '[ в , плане ]',
#  '[ нужно , положить , деньги , в , россии , и , снять , в , германии ]',
#  '[ мы , не , идём ]',
#  '[ мы , лиза , и , даша ]',
#  '[ пока , нет ]',
#  '[ не , писали ]',
#  '[ грустно , это ]',
#  '[ а , что , ты , написал ]',
#  '[ мы , с , дашей , болеем ]',
#  '[ придумать , что - то , еще ]',
#  '[ да , зачем , оправдываться ]',
#  '[ более , того , это , ctrl , c , -, ctrl , v ]',
#  '[ марк , меняй , аву ]',
#  '[ сейчас , прям ]',
#  '[ не , знаю ]',
#  '[ на , что , нравится ]',
#  '[ да , мне , он , так , и , не , нужен ]',
#  '[ это , сестра , что - то , пытается ]',
#  '[ но , я , хочу , изучить , немного , всю , эту , тему ]',
#  '[ хоть , немного , понимать ]',
#  '[ но , деньги , хотелось , бы , закинуть ]',
#  '[ тогда , если , купишь ]',
#  '[ опять , мухомор ]',
#  '[ поставь , тогда , реальный , мухомор ]',
#  '[ зато , интересно ]',
#  '[ если , честно ]',
#  '[ думаю , что , ты , бы , его , не , съел ]',
#  '[ удобнее , его , кому - то , подсунуть ]',
#  '[ и , глянуть , что , да , как ]',
#  '[ на , это , и , рассчитано ]',
#  '[ пока , нет ]',
#  '[ я , потом , свою , фотку , поставлю ]',
#  '[ когда , сделаю , что - то , хорошее ]',
#  '[ пока , так ]',
#  '[ и , что , это , было ]',
#  '[ я , бы , оч , испугалась , наверное ]',
#  '[ в , смысле , где , конкретно ]',
#  '[ город , же , сказал ]',
#  '[ населенный , пункт ]',
#  '[ а , что , она , еще , хотела ]',
#  '[ ваня , теперь , будет , с , приятной , компанией , спать ]',
#  '[ я , гуляю ]',
#  '[ пока , что , отвечаю , пошли ]',
#  '[ я , же , предлагала ]',
#  '[ кинб , пока , афишу , я , позже , отвечу ]',
#  '[ у , тебя , винда , на , компе ]',
#  '[ вот , и , я , об , этом ]',
#  '[ но , хочется , верить , что , не , пиратская ]',
#  '[ хочу , сбросить ]',
#  '[ потому , что , не , огу , очистить , вручную ]',
#  '[ тут , чел , веселый , рассказывает , как , установить , винду ]',
#  '[ шутки , на , 100 , баллов ]',
#  '[ да , это , понятно ]',
#  '[ я , уже , час , видео , смотрю ]',
#  '[ запиши , видео , где , вы , просто , смотрите , в , камеру , и , ничего , не , говорите ]',
#  '[ 10 , сек , минимум ]',
#  '[ я , блондинка , теперь ]',
#  '[ ты , же , знаешь , да ]',
#  '[ ну , относительно , блондинка ]',
#  '[ там , переход , на , волосах ]',
#  '[ корни , мои ]',
#  '[ концы , белые ]',
#  '[ у , вани , была , ща ]',
#  '[ я , с , компа ]',
#  '[ я , больше , не , хочу , быть , русой ]',
#  '[ белку , ищут ]',
#  '[ а , ты , не , спрятался ]',
#  '[ это , кто ]',
#  '[ а , кто , это ]',
#  '[ музыка , топ ]',
#  '[ тут , у , одной , девушки , свадьба ]',
#  '[ мне , захотелось , оч , на , свадьбу ]',
#  '[ с , тобой , сложно , заскучать ]',
#  '[ я , просто , счастлива ]',
#  '[ я , из - за , винды , немного , тревожилась ]',
#  '[ а , есть , разница , в , браузерах ]',
#  '[ в , плане , функционала ]',
#  '[ да , не ]',
#  '[ его , нахуй ]',
#  '[ я , между , яндексом , и , хромом , выбираю ]',
#  '[ не , хочу ]',
#  '[ мне , нравятся , сервисы , яндекс ]',
#  '[ карты , почта ]',
#  '[ я , часто , ими , пользуюсь ]',
#  '[ типо , шума , много ]',
#  '[ в , разнос , пошел ]',
#  '[ такой , марк , мне , нравится , очень ]',
#  ...]

# %%
from tqdm import tqdm
from collections import defaultdict, Counter

# special tokens: 
# - unk represents absent tokens, 
# - eos is a special token after the end of sequence

UNK, EOS = "_UNK_", "_EOS_"

def count_ngrams(lines, n):
    """
    Count how many times each word occured after (n - 1) previous words
    :param lines: an iterable of strings with space-separated tokens
    :returns: a dictionary { tuple(prefix_tokens): {next_token_1: count_1, next_token_2: count_2}}

    When building counts, please consider the following two edge cases
    - if prefix is shorter than (n - 1) tokens, it should be padded with UNK. For n=3,
      empty prefix: "" -> (UNK, UNK)
      short prefix: "the" -> (UNK, the)
      long prefix: "the new approach" -> (new, approach)
    - you should add a special token, EOS, at the end of each sequence
      "... with deep neural networks ." -> (..., with, deep, neural, networks, ., EOS)
      count the probability of this token just like all others.
    """
    counts = defaultdict(Counter)
    # counts[(word1, word2)][word3] = how many times word3 occured after (word1, word2)

    for line in tqdm(lines, desc='N-grams'):
        unk_prefix = ' '.join([UNK] * (n - 1))
        eos_suffix = EOS
        tokens = f'{unk_prefix} {line} {eos_suffix}'.split()
        for i in range(n - 1, len(tokens)):
            n_gram = tuple(tokens[i - n + 1: i])
            counts[n_gram].update([tokens[i]])

    
    return counts

# %%
# let's test it
dummy_lines = sorted(lines, key=len)[:100]
dummy_counts = count_ngrams(dummy_lines, n=3)
# Out:
# N-grams: 100%|██████████| 100/100 [00:00<00:00, 71624.04it/s]

# %%
dummy_counts[('_UNK_', 'a')]
# Out:
# Counter()

# %%
class NGramLanguageModel:    
    def __init__(self, lines, n):
        """ 
        Train a simple count-based language model: 
        compute probabilities P(w_t | prefix) given ngram counts
        
        :param n: computes probability of next token given (n - 1) previous words
        :param lines: an iterable of strings with space-separated tokens
        """
        assert n >= 1
        self.n = n
    
        counts = count_ngrams(lines, self.n)
        
        # compute token proabilities given counts
        self.probs = defaultdict(Counter)
        # probs[(word1, word2)][word3] = P(word3 | word1, word2)
        
        # populate self.probs with actual probabilities
        for k,v in tqdm(counts.items()):
            s = sum(v.values())
            for word, cout in v.items():
                self.probs[k][word] = counts[k][word] / s 
            
    def get_possible_next_tokens(self, prefix):
        """
        :param prefix: string with space-separated prefix tokens
        :returns: a dictionary {token : it's probability} for all tokens with positive probabilities
        """
        prefix = prefix.split()
        prefix = prefix[max(0, len(prefix) - self.n + 1):]
        prefix = [ UNK ] * (self.n - 1 - len(prefix)) + prefix
        return self.probs[tuple(prefix)]
    
    def get_next_token_prob(self, prefix, next_token):
        """
        :param prefix: string with space-separated prefix tokens
        :param next_token: the next token to predict probability for
        :returns: P(next_token|prefix) a single number, 0 <= P <= 1
        """
        return self.get_possible_next_tokens(prefix).get(next_token, 0)

# %%
dummy_lm = NGramLanguageModel(dummy_lines, n=3)

p_initial = dummy_lm.get_possible_next_tokens('') # '' -> ['_UNK_', '_UNK_']

assert dummy_lm.get_possible_next_tokens('марк') == \
    dummy_lm.get_possible_next_tokens("привет"), \
    "как дела"
# Out:
# N-grams: 100%|██████████| 100/100 [00:00<00:00, 117817.53it/s]
# 100%|██████████| 173/173 [00:00<00:00, 309035.18it/s]

# %%
p_initial
# Out:
# Counter({'[': 1.0})

# %%
lm = NGramLanguageModel(lines, n=3)
# Out:
# N-grams: 100%|██████████| 3542/3542 [00:00<00:00, 78082.57it/s]
# 100%|██████████| 11260/11260 [00:00<00:00, 603882.81it/s]

# %%
def get_next_token(lm, prefix, temperature=1.0):
    """
    return next token after prefix;
    :param temperature: samples proportionally to lm probabilities ^ (1 / temperature)
        if temperature == 0, always takes most likely token. Break ties arbitrarily.
    """
    next_tokens = lm.get_possible_next_tokens(prefix)
    if temperature == 0:
        sorted_next_tokens = dict(
            sorted(tuple(next_tokens.items()), key=lambda x:x[1], 
                   reverse=True)
        )
        next_token = tuple(sorted_next_tokens.items())[0][0]
    else:
        sum_probs = sum([
            prob ** (1 / temperature) for prob in next_tokens.values()
        ])

        next_tokens = {
            token: prob ** (1 / temperature) / sum_probs
            for token, prob in next_tokens.items()
        }
        tokens = list(next_tokens.keys())
        probs = list(next_tokens.values())
        next_token = np.random.choice(tokens, 1, p=probs)[0]
    return next_token

# %%
from collections import Counter
test_freqs = Counter([get_next_token(lm, 'марк') for _ in range(10000)])


test_freqs = Counter([get_next_token(lm, 'have', temperature=1.0) for _ in range(20000)])
test_freqs = Counter([get_next_token(lm, 'have', temperature=0.5) for _ in range(20000)])
test_freqs = Counter([get_next_token(lm, 'have', temperature=0.0) for _ in range(20000)])

print("Looks nice!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 from collections import Counter
# ----> 2 test_freqs = Counter([get_next_token(lm, 'марк') for _ in range(10000)])
#       5 test_freqs = Counter([get_next_token(lm, 'have', temperature=1.0) for _ in range(20000)])
#       6 test_freqs = Counter([get_next_token(lm, 'have', temperature=0.5) for _ in range(20000)])
#
# Cell In[34], line 2, in <listcomp>(.0)
#       1 from collections import Counter
# ----> 2 test_freqs = Counter([get_next_token(lm, 'марк') for _ in range(10000)])
#       5 test_freqs = Counter([get_next_token(lm, 'have', temperature=1.0) for _ in range(20000)])
#       6 test_freqs = Counter([get_next_token(lm, 'have', temperature=0.5) for _ in range(20000)])
#
# Cell In[33], line 25, in get_next_token(lm, prefix, temperature)
#      23     tokens = list(next_tokens.keys())
#      24     probs = list(next_tokens.values())
# ---> 25     next_token = np.random.choice(tokens, 1, p=probs)[0]
#      26 return next_token
#
# File mtrand.pyx:934, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: 'a' cannot be empty unless no samples are taken

# %%
prefix = 'марк' # <- your ideas :)

for i in range(100):
    prefix += ' ' + get_next_token(lm, prefix)
    if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
        break
        
print(prefix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 4
#       1 prefix = 'марк' # <- your ideas :)
#       3 for i in range(100):
# ----> 4     prefix += ' ' + get_next_token(lm, prefix)
#       5     if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
#       6         break
#
# Cell In[21], line 25, in get_next_token(lm, prefix, temperature)
#      23     tokens = list(next_tokens.keys())
#      24     probs = list(next_tokens.values())
# ---> 25     next_token = np.random.choice(tokens, 1, p=probs)[0]
#      26 return next_token
#
# File mtrand.pyx:934, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: 'a' cannot be empty unless no samples are taken

# %%
prefix = 'interesting prophecies' # <- more of your ideas

for i in range(100):
    prefix += ' ' + get_next_token(lm, prefix, temperature=0.5)
    if prefix.endswith(EOS) or len(lm.get_possible_next_tokens(prefix)) == 0:
        break
        
print(prefix)
# Out:
# interesting prophecies , of course , but nevertheless we were informed that another war had followed the first world war _EOS_

# %%
def perplexity(lm, lines, min_logprob=np.log(10 ** -7.)):
    """
    :param lines: a list of strings with space-separated tokens
    :param min_logprob: if log(P(w | ...)) is smaller than min_logprop, set it equal to min_logrob
    :returns: corpora-level perplexity - a single scalar number from the formula above
    
    Note: do not forget to compute P(w_first | empty) and P(eos | full_sequence)
    
    PLEASE USE lm.get_next_token_prob and NOT lm.get_possible_next_tokens
    """
    total_length = 0
    log_pp = 0

    for line in tqdm(lines):
        tokens = [''] + line.split(' ') + [EOS]

        for t in range(1, len(tokens)):
            prefix = ' '.join(tokens[:t])
            log_pp += max(
                min_logprob, np.log(lm.get_next_token_prob(prefix, tokens[t]))
            )
            total_length += 1
    
    return np.exp(-( 1 / total_length) * log_pp)

# %%
lm1 = NGramLanguageModel(dummy_lines, n=1)
lm3 = NGramLanguageModel(dummy_lines, n=3)
lm10 = NGramLanguageModel(dummy_lines, n=10)

ppx1 = perplexity(lm1, dummy_lines)
ppx3 = perplexity(lm3, dummy_lines)
ppx10 = perplexity(lm10, dummy_lines)
ppx_missing = perplexity(lm3, ['the jabberwock , with eyes of flame , '])  # thanks, L. Carrol

print("Perplexities: ppx1=%.3f ppx3=%.3f ppx10=%.3f" % (ppx1, ppx3, ppx10))

assert all(0 < ppx < 500 for ppx in (ppx1, ppx3, ppx10)), "perplexity should be nonnegative and reasonably small"
assert ppx1 > ppx3 > ppx10, "higher N models should overfit and "
assert np.isfinite(ppx_missing) and ppx_missing > 10 ** 6, "missing words should have large but finite perplexity. " \
    " Make sure you use min_logprob right"
# Out:
# N-grams: 100%|██████████| 100/100 [00:00<00:00, 162822.36it/s]
# 100%|██████████| 1/1 [00:00<00:00, 7244.05it/s]
# N-grams: 100%|██████████| 100/100 [00:00<00:00, 107216.36it/s]
# 100%|██████████| 321/321 [00:00<00:00, 450894.70it/s]
# N-grams: 100%|██████████| 100/100 [00:00<00:00, 109312.07it/s]
# 100%|██████████| 333/333 [00:00<00:00, 473779.93it/s]
# 100%|██████████| 100/100 [00:00<00:00, 68456.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 68122.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 64937.36it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]/var/folders/rr/39767lj15dg81g2dbl4jq3rw0000gn/T/ipykernel_56988/1886438417.py:20: RuntimeWarning: divide by zero encountered in log
#   min_logprob, np.log(lm.get_next_token_prob(prefix, tokens[t]))
# 100%|██████████| 1/1 [00:00<00:00, 5841.65it/s]
# Perplexities: ppx1=86.300 ppx3=2.654 ppx10=2.593

# %%
from sklearn.model_selection import train_test_split
train_lines, test_lines = train_test_split(lines, test_size=0.25, random_state=42)

for n in (1, 2, 3):
    lm = NGramLanguageModel(n=n, lines=train_lines)
    ppx = perplexity(lm, test_lines)
    print("N = %i, Perplexity = %.5f" % (n, ppx))
# Out:
# N-grams: 100%|██████████| 1125/1125 [00:00<00:00, 60070.43it/s]
# 100%|██████████| 1/1 [00:00<00:00, 1062.66it/s]
#   0%|          | 0/375 [00:00<?, ?it/s]/var/folders/rr/39767lj15dg81g2dbl4jq3rw0000gn/T/ipykernel_56988/1886438417.py:20: RuntimeWarning: divide by zero encountered in log
#   min_logprob, np.log(lm.get_next_token_prob(prefix, tokens[t]))
# 100%|██████████| 375/375 [00:00<00:00, 13915.83it/s]
# N = 1, Perplexity = 851.52224
# N-grams: 100%|██████████| 1125/1125 [00:00<00:00, 45628.17it/s]
# 100%|██████████| 4007/4007 [00:00<00:00, 417824.59it/s]
# 100%|██████████| 375/375 [00:00<00:00, 11182.43it/s]
# N = 2, Perplexity = 14903.66023
# N-grams: 100%|██████████| 1125/1125 [00:00<00:00, 33844.68it/s]
# 100%|██████████| 15712/15712 [00:00<00:00, 671717.95it/s]
# 100%|██████████| 375/375 [00:00<00:00, 8545.62it/s]
# N = 3, Perplexity = 639725.17200

# %%
class LaplaceLanguageModel(NGramLanguageModel): 
    """ this code is an example, no need to change anything """
    def __init__(self, lines, n, delta=1.0):
        self.n = n
        counts = count_ngrams(lines, self.n)
        self.vocab = set(token for token_counts in counts.values() for token in token_counts)
        self.probs = defaultdict(Counter)

        for prefix in counts:
            token_counts = counts[prefix]
            total_count = sum(token_counts.values()) + delta * len(self.vocab)
            self.probs[prefix] = {token: (token_counts[token] + delta) / total_count
                                          for token in token_counts}
    def get_possible_next_tokens(self, prefix):
        token_probs = super().get_possible_next_tokens(prefix)
        missing_prob_total = 1.0 - sum(token_probs.values())
        missing_prob = missing_prob_total / max(1, len(self.vocab) - len(token_probs))
        return {token: token_probs.get(token, missing_prob) for token in self.vocab}
    
    def get_next_token_prob(self, prefix, next_token):
        token_probs = super().get_possible_next_tokens(prefix)
        if next_token in token_probs:
            return token_probs[next_token]
        else:
            missing_prob_total = 1.0 - sum(token_probs.values())
            missing_prob_total = max(0, missing_prob_total) # prevent rounding errors
            return missing_prob_total / max(1, len(self.vocab) - len(token_probs))

# %%
#test that it's a valid probability model
for n in (1, 2, 3):
    dummy_lm = LaplaceLanguageModel(dummy_lines, n=n)
    assert np.allclose(sum([dummy_lm.get_next_token_prob('a', w_i) for w_i in dummy_lm.vocab]), 1), "I told you not to break anything! :)"
# Out:
# N-grams: 100%|██████████| 100/100 [00:00<00:00, 166639.01it/s]
# N-grams: 100%|██████████| 100/100 [00:00<00:00, 151802.53it/s]
# N-grams: 100%|██████████| 100/100 [00:00<00:00, 150387.38it/s]

# %%
for n in (1, 2, 3):
    lm = LaplaceLanguageModel(train_lines, n=n, delta=0.1)
    ppx = perplexity(lm, test_lines)
    print("N = %i, Perplexity = %.5f" % (n, ppx))
# Out:
# N-grams: 100%|██████████| 1125/1125 [00:00<00:00, 53744.95it/s]
# 100%|██████████| 375/375 [00:00<00:00, 9209.45it/s]
# N = 1, Perplexity = 854.38045
# N-grams: 100%|██████████| 1125/1125 [00:00<00:00, 45351.89it/s]
# 100%|██████████| 375/375 [00:00<00:00, 10297.72it/s]
# N = 2, Perplexity = 810.43758
# N-grams: 100%|██████████| 1125/1125 [00:00<00:00, 34684.82it/s]
# 100%|██████████| 375/375 [00:00<00:00, 10142.21it/s]
# N = 3, Perplexity = 2224.67414

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
# %matplotlib inline

# %%
sorted(lines, key=len)[:3]

# Task: convert lines (in-place) into strings of space-separated tokens. import & use WordPunctTokenizer
from nltk import WordPunctTokenizer
tokenizer = WordPunctTokenizer()
lines = [
    ' '.join(
        tokenizer.tokenize(line.lower())
    ) for line in tqdm(lines)
]
# Out:
#   0%|          | 0/1500 [00:00<?, ?it/s]

# %%
train, valid = train_test_split(lines, test_size=0.2)
lm_datasets = {'train' : train, 'valid' : valid}

# %%
from datasets import Dataset
my_dict = {"text": lines}
datasets = Dataset.from_dict(my_dict)
tr_test_datasets = datasets.train_test_split(test_size=0.1)

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML
from sklearn.model_selection import train_test_split

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    for column, typ in dataset.features.items():
        if isinstance(typ, ClassLabel):
            df[column] = df[column].transform(lambda i: typ.names[i])
    display(HTML(df.to_html()))

# %%
clm_model_checkpoint = "gpt2"
clm_tokenizer_checkpoint = "gpt2"

# %%
from transformers import GPT2Tokenizer, GPT2Model, AutoModelForCausalLM
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# model = AutoModelForCausalLM.from_pretrained('gpt2')
model = AutoModelForCausalLM.from_pretrained('zaaabik/gpt2-arxiv-clm')

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"])

# %%
tokenized_datasets = tr_test_datasets.map(tokenize_function, 
                                          batched=True, num_proc=4, 
                                          remove_columns=["text"])
# Out:
# Map (num_proc=4):   0%|          | 0/1350 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/150 [00:00<?, ? examples/s]

# %%
block_size = 128

# %%
def group_texts(examples):
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the small remainder, we could add padding if the model supported it instead of this drop, you can
        # customize this part to your needs.
    total_length = (total_length // block_size) * block_size
    # Split by chunks of max_len.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

# %%
lm_datasets = tokenized_datasets.map(
    group_texts,
    batched=True,
    batch_size=1000,
    num_proc=4,
)
# Out:
# Map (num_proc=4):   0%|          | 0/1350 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/150 [00:00<?, ? examples/s]

# %%
lm_datasets['train'][1]['labels']
# Out:
# [345,
#  760,
#  837,
#  356,
#  423,
#  845,
#  1310,
#  1364,
#  287,
#  262,
#  835,
#  286,
#  4406,
#  286,
#  262,
#  3307,
#  286,
#  326,
#  1175,
#  837,
#  326,
#  318,
#  837,
#  262,
#  7141,
#  3403,
#  739,
#  543,
#  340,
#  373,
#  8350,
#  837,
#  290,
#  262,
#  10815,
#  9322,
#  732,
#  550,
#  925,
#  617,
#  7838,
#  1626,
#  262,
#  4074,
#  72,
#  5220,
#  284,
#  683,
#  284,
#  423,
#  262,
#  1450,
#  900,
#  510,
#  511,
#  890,
#  532,
#  6541,
#  8776,
#  319,
#  281,
#  26726,
#  9197,
#  7346,
#  262,
#  15228,
#  1456,
#  373,
#  1194,
#  922,
#  1738,
#  329,
#  262,
#  6482,
#  287,
#  616,
#  3352,
#  1169,
#  16408,
#  4430,
#  2607,
#  13892,
#  262,
#  7025,
#  286,
#  262,
#  1708,
#  1779,
#  25742,
#  286,
#  663,
#  6496,
#  13050,
#  1058,
#  262,
#  40733,
#  18814,
#  284,
#  257,
#  2292,
#  2029,
#  262,
#  266,
#  88,
#  3383,
#  19272,
#  810,
#  262,
#  15228,
#  286,
#  262,
#  308,
#  74,
#  532,
#  860,
#  5705,
#  373,
#  1900,
#  284,
#  307,
#  837,
#  422,
#  262,
#  1700,
#  286,
#  663,
#  4067,
#  1064]

# %%
lm_datasets['train'][1]['input_ids'][:10]
# Out:
# [345, 760, 837, 356, 423, 845, 1310, 1364, 287, 262]

# %%
from transformers import Trainer, TrainingArguments

# %%
training_args = TrainingArguments(
    f"gpt2-arxiv-clm",
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    weight_decay=0.01,
    # push_to_hub=True
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=lm_datasets['train'],
    eval_dataset=lm_datasets['test'],
)

# %%
trainer.train()
# Out:
# /opt/anaconda3/envs/torch/lib/python3.9/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 248
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 93
#   Number of trainable parameters = 124439808
#   0%|          | 0/93 [00:00<?, ?it/s]
# ***** Running Evaluation *****
#   Num examples = 29
#   Batch size = 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'eval_loss': 4.560611248016357, 'eval_runtime': 6.8201, 'eval_samples_per_second': 4.252, 'eval_steps_per_second': 0.587, 'epoch': 1.0}
# ***** Running Evaluation *****
#   Num examples = 29
#   Batch size = 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# {'eval_loss': 4.407764911651611, 'eval_runtime': 6.6939, 'eval_samples_per_second': 4.332, 'eval_steps_per_second': 0.598, 'epoch': 2.0}
# ***** Running Evaluation *****
#   Num examples = 29
#   Batch size = 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# Training completed. Do not forget to share your model on huggingface.co/models =)
# {'eval_loss': 4.364953994750977, 'eval_runtime': 7.1259, 'eval_samples_per_second': 4.07, 'eval_steps_per_second': 0.561, 'epoch': 3.0}
# {'train_runtime': 627.2816, 'train_samples_per_second': 1.186, 'train_steps_per_second': 0.148, 'train_loss': 4.632142425865255, 'epoch': 3.0}
# TrainOutput(global_step=93, training_loss=4.632142425865255, metrics={'train_runtime': 627.2816, 'train_samples_per_second': 1.186, 'train_steps_per_second': 0.148, 'train_loss': 4.632142425865255, 'epoch': 3.0})

# %%
import math
eval_results = trainer.evaluate()
print(f"Perplexity: {math.exp(eval_results['eval_loss']):.2f}")
# Out:
# ***** Running Evaluation *****
#   Num examples = 29
#   Batch size = 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# Perplexity: 78.65
